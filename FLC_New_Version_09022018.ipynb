# %% [markdown]
# # Facility List Coder, version 12/02/2018

# %% [markdown]
# The Facility List coder (FLC) is an open source tool that allow efficiently combine GIS analysis with standard data techniques. Besides the data management tools, FLC code retrieves GIS information on facilities location using two open source datasets: Google Maps and Open Street Maps.
#
# FLC is built upon two main requirements.
# - First, researchers will need to provide a specific data set for the specific location of the reference point (e.g. school, university, among others). We call them as location of interest (LI).
# - Second in order to classify the results obtained from the spatial query on the traditional GIS engines, researchers will need to define a set of key words or metadata that allow the algorithm classify the facilities. Based on the literature (Caspi et al. 2012; Lytle and Sokol 2017; Wilkins et al. 2017), we have developed a multi-language key words list based on the European context that allows to classify each facility within a pre-defined category. These categories could be modified in order to fulfill specific needs of researchers related to geographical location, languages or research questions. This pre-defined key word offers an important innovation for the research on food community environment in the European context. The empirical studies for Europe often use categories created for United States, which might miss-estimate the particularities of European food traditions. Nonetheless, this list will be easily extended depending on the needs of the researchers. We called this dimension as key words by categories (KW).

# %% [markdown]
# ## Code Preliminaries

# %% [markdown]
# FLC code retrieves GIS information on facilities location using two open source datasets: Google Maps and Open Street Maps. All the code was developed on Python 2.7.

# %% [markdown]
# ###  Defining functions

# %% [markdown]
# Now, we need to create functions that will be use during the process

# %%
### Function to save results 
## 
def save_result(res,prints):
    for place in res.places:
        place.get_details()
        if prints==1:
            print place.name.encode('utf-8'),place.types,place.place_id
        else:
            if place.place_id not in places_flc:
                raw={'place_name':place.name,'place_lat':float(place.geo_location['lat']),'place_lng':float(place.geo_location['lng']),'place_address':place.formatted_address,'google_id':place.place_id,'place_types':place.types,'place_web':place.url}
                places_flc[place.place_id]=raw
                    

## Read 
## This functions was made to test the results
def read_result(res):
    for place in res.places:
        place.get_details()
        print place.name.encode('utf-8'),place.types,place.place_id
    
                
### Save Results
## Save Results
def sav_final(place,cat,final_ds):
    ## Save Final Data Set
    raw=places_flc_cleaned[place]
    raw['categ']=cat
    final_ds.append(raw)
    ## Delete the dictionary

# %% [markdown]
# ### Loading packages

# %% [markdown]
# Here we need to load the needed packages

# %%
# coding=utf-8
###########################
###### Libraries and Initial SetUp
###########################

### My Data key
YOUR_API_KEY = 'AIzaSyBfLqFQrm0zGqqHooHxEDgvlfq1_FXQTWw'

## --- Google maps
import googlemaps
gmaps = googlemaps.Client(key=YOUR_API_KEY)
from datetime import datetime

# ----- Google Place
from googleplaces import GooglePlaces, types, lang
import google_streetview.api
google_places = GooglePlaces(YOUR_API_KEY)

# ----- Download the data
import urllib2 # Download the files
import os, sys ## create a new 
import pandas as pd
from xlsxwriter.utility import xl_rowcol_to_cell

# ------ from openpyxl import load_workbook
from openpyxl import load_workbook
import fiona

# ------ Import Regex
import re

# ----- Load information
import json

# %% [markdown]
# ## Input 1:  Key Words

# %% [markdown]
# In this section we load the key words that will be used for the classification of the results.

# %% [markdown]
# ### Key words for the Catalan context

# %% [markdown]
# The first part of the key words are a detailed description of the economic activities in a specific region. In the case of Catalunya, we employed: "Criteris registrals pe a establiments minoristes d'alimentació en Catalunya" from the Regional Government. This document brings a details description of the different types of establishments present in the region.
#
# All the keywords were translated in English, Spanish and Catalan. Everything is save at: **Palabras_clave_v0_120917.xlsx**

# %%
data_keywords="/Users/juancarlosmunoz/Dropbox/Obsogenic_Project/01_DataBase_Georeferencion/Palabras_clave_v0_120917.xlsx"
wb = load_workbook(filename = data_keywords)
palabras = wb['Plabras_Claves_Google']

### Create the dictionary
categ_est={}
keywords=[]
for row in range(2,54):
    cat=str(palabras.cell(row=row, column=1).value.encode('utf-8')).lower().strip()
    try:
        categ_est[cat]=[]
    except:
        pass

#### Now the key words
for row in range(2,54):
    cat=str(palabras.cell(row=row, column=1).value.encode('utf-8')).lower().strip()
    for col in [2,3,4]:
        if palabras.cell(row=row, column=col).value is not None:
            word=str(palabras.cell(row=row, column=col).value.encode('utf-8')).lower().strip()
            if word not in categ_est[cat]:
                categ_est[cat].append(str(word))

# %% [markdown]
# ### Type Excluded

# %% [markdown]
# In order to optimize the query over the google maps we restrict the search to particular set of places types ([here the list of accepted types in Google](https://developers.google.com/places/supported_types)).
#
# In order to exclude/include a given category you only have to change: **google_types.xlsx**

# %%
data_types="/Users/juancarlosmunoz/Dropbox/Obsogenic_Project/01_DataBase_Georeferencion/google_types.xlsx"
wb = load_workbook(filename = data_types)
palabras = wb['Sheet1']
types_accepted=[]
types_excluded=[]
for row in range(2,98):
    selected=int(palabras.cell(row=row, column=2).value)
    if selected==0:
        types_accepted.append(str(palabras.cell(row=row, column=1).value))
    if selected==1:
        types_excluded.append(str(palabras.cell(row=row, column=1).value))

print types_accepted
# Out:
# ['bakery', 'bar', 'cafe', 'convenience_store', 'establishment', 'food', 'grocery_or_supermarket', 'liquor_store', 'meal_delivery', 'meal_takeaway', 'restaurant', 'shopping_mall', 'store']

# %% [markdown]
# ## Input 2: Defining Location  of interest (LI)

# %% [markdown]
# In this section we load the location of the point of interest. For the validation procedure, we include the Grids.
#
# Note that you need a shapefile with the centroids. It can be generalized even more using any type of argument.

# %%
grids="/Users/juancarlosmunoz/Dropbox/Familia_Munoz_Arcila/05_Paper/shp/final_sample_15122017_centroids_WSG84.shp"
grids_data={}
with fiona.open(grids,'r') as shp:
    for feat in shp:
        grid_id=feat['properties']['grid_id']
        lng,lat=feat['geometry']['coordinates']
        grids_data[grid_id]={'lat':lat,'lng':lng}

# %% [markdown]
# ## Facility List Coder in action: Building the dataset

# %% [markdown]
# In this section we run the spatial query in Google maps based on the point of interest. Technically, the FLC will get all the location within an specific folder, then we will classify then using the key words.
#
# The first step is defining the data set.

# %%
# Data Information
places_flc={}

# %% [markdown]
# ### Spatial Query Strategy 1: Using only Google types

# %% [markdown]
# This strategy will get all the places within a buffer that belongs to a specific type (look above to check the list o types

# %% [markdown]
# ### Spatial Query Strategy 2: Using only Google types

# %%
i=1

### To Print results
prints=0

#for grid in [755]:
for grid in grids_data:
    print "%d of 301 (grid=%d)" %(i,grid)
    i+=1
    ### First Step Search
    for typ in types_accepted:
   #for typ in ['restaurant']:
        ### First 20 results
        res1=google_places.nearby_search(lat_lng=grids_data[grid],radius=100,types=[typ])
        save_result(res1,prints)
        # For more than 20 results
        try:
            res2 = google_places.nearby_search(pagetoken=res1.next_page_token)
            save_result(res2,prints)
            try:
                res3 = google_places.nearby_search(pagetoken=res2.next_page_token)
                save_result(res3,prints)
                try:
                    res4 = google_places.nearby_search(pagetoken=res3.next_page_token)
                    save_result(res4,prints)
                except:
                    pass  
            except:
                pass    
        except:
            pass
# Out:
# 1 of 301 (grid=1)
# 2 of 301 (grid=683)
# 3 of 301 (grid=4)
# 4 of 301 (grid=6)
# 5 of 301 (grid=290)
# 6 of 301 (grid=273)
# 7 of 301 (grid=525)
# 8 of 301 (grid=526)
# 9 of 301 (grid=173)
# 10 of 301 (grid=17)
# 11 of 301 (grid=1042)
# 12 of 301 (grid=515)
# 13 of 301 (grid=529)
# 14 of 301 (grid=23)
# 15 of 301 (grid=1049)
# 16 of 301 (grid=538)
# 17 of 301 (grid=1052)
# 18 of 301 (grid=1054)
# 19 of 301 (grid=543)
# 20 of 301 (grid=32)
# 21 of 301 (grid=474)
# 22 of 301 (grid=1058)
# 23 of 301 (grid=35)
# 24 of 301 (grid=1062)
# 25 of 301 (grid=1063)
# 26 of 301 (grid=553)
# 27 of 301 (grid=42)
# 28 of 301 (grid=555)
# 29 of 301 (grid=1069)
# 30 of 301 (grid=558)
# 31 of 301 (grid=1071)
# 32 of 301 (grid=560)
# 33 of 301 (grid=49)
# 34 of 301 (grid=947)
# 35 of 301 (grid=862)
# 36 of 301 (grid=568)
# 37 of 301 (grid=1082)
# 38 of 301 (grid=1127)
# 39 of 301 (grid=63)
# 40 of 301 (grid=64)
# 41 of 301 (grid=1089)
# 42 of 301 (grid=331)
# 43 of 301 (grid=69)
# 44 of 301 (grid=584)
# 45 of 301 (grid=587)
# 46 of 301 (grid=588)
# 47 of 301 (grid=589)
# 48 of 301 (grid=78)
# 49 of 301 (grid=1104)
# 50 of 301 (grid=1107)
# 51 of 301 (grid=84)
# 52 of 301 (grid=270)
# 53 of 301 (grid=86)
# 54 of 301 (grid=1111)
# 55 of 301 (grid=601)
# 56 of 301 (grid=1114)
# 57 of 301 (grid=603)
# 58 of 301 (grid=395)
# 59 of 301 (grid=93)
# 60 of 301 (grid=606)
# 61 of 301 (grid=471)
# 62 of 301 (grid=1124)
# 63 of 301 (grid=615)
# 64 of 301 (grid=1131)
# 65 of 301 (grid=108)
# 66 of 301 (grid=274)
# 67 of 301 (grid=1134)
# 68 of 301 (grid=701)
# 69 of 301 (grid=624)
# 70 of 301 (grid=113)
# 71 of 301 (grid=1138)
# 72 of 301 (grid=627)
# 73 of 301 (grid=1140)
# 74 of 301 (grid=629)
# 75 of 301 (grid=118)
# 76 of 301 (grid=1143)
# 77 of 301 (grid=1145)
# 78 of 301 (grid=634)
# 79 of 301 (grid=123)
# 80 of 301 (grid=1149)
# 81 of 301 (grid=638)
# 82 of 301 (grid=127)
# 83 of 301 (grid=1368)
# 84 of 301 (grid=107)
# 85 of 301 (grid=647)
# 86 of 301 (grid=648)
# 87 of 301 (grid=655)
# 88 of 301 (grid=1169)
# 89 of 301 (grid=659)
# 90 of 301 (grid=661)
# 91 of 301 (grid=662)
# 92 of 301 (grid=25)
# 93 of 301 (grid=397)
# 94 of 301 (grid=153)
# 95 of 301 (grid=667)
# 96 of 301 (grid=1180)
# 97 of 301 (grid=1181)
# 98 of 301 (grid=159)
# 99 of 301 (grid=1136)
# 100 of 301 (grid=163)
# 101 of 301 (grid=164)
# 102 of 301 (grid=198)
# 103 of 301 (grid=497)
# 104 of 301 (grid=167)
# 105 of 301 (grid=1192)
# 106 of 301 (grid=169)
# 107 of 301 (grid=682)
# 108 of 301 (grid=1195)
# 109 of 301 (grid=626)
# 110 of 301 (grid=686)
# 111 of 301 (grid=687)
# 112 of 301 (grid=712)
# 113 of 301 (grid=1202)
# 114 of 301 (grid=1139)
# 115 of 301 (grid=1206)
# 116 of 301 (grid=1207)
# 117 of 301 (grid=347)
# 118 of 301 (grid=799)
# 119 of 301 (grid=1212)
# 120 of 301 (grid=1213)
# 121 of 301 (grid=702)
# 122 of 301 (grid=703)
# 123 of 301 (grid=707)
# 124 of 301 (grid=710)
# 125 of 301 (grid=199)
# 126 of 301 (grid=1224)
# 127 of 301 (grid=1225)
# 128 of 301 (grid=859)
# 129 of 301 (grid=1227)
# 130 of 301 (grid=1228)
# 131 of 301 (grid=34)
# 132 of 301 (grid=206)
# 133 of 301 (grid=1231)
# 134 of 301 (grid=208)
# 135 of 301 (grid=722)
# 136 of 301 (grid=724)
# 137 of 301 (grid=462)
# 138 of 301 (grid=726)
# 139 of 301 (grid=215)
# 140 of 301 (grid=1240)
# 141 of 301 (grid=1241)
# 142 of 301 (grid=1371)
# 143 of 301 (grid=719)
# 144 of 301 (grid=732)
# 145 of 301 (grid=1146)
# 146 of 301 (grid=1248)
# 147 of 301 (grid=226)
# 148 of 301 (grid=1251)
# 149 of 301 (grid=741)
# 150 of 301 (grid=230)
# 151 of 301 (grid=178)
# 152 of 301 (grid=744)
# 153 of 301 (grid=235)
# 154 of 301 (grid=236)
# 155 of 301 (grid=210)
# 156 of 301 (grid=1265)
# 157 of 301 (grid=755)
# 158 of 301 (grid=244)
# 159 of 301 (grid=1150)
# 160 of 301 (grid=1270)
# 161 of 301 (grid=41)
# 162 of 301 (grid=468)
# 163 of 301 (grid=639)
# 164 of 301 (grid=765)
# 165 of 301 (grid=255)
# 166 of 301 (grid=768)
# 167 of 301 (grid=769)
# 168 of 301 (grid=771)
# 169 of 301 (grid=470)
# 170 of 301 (grid=262)
# 171 of 301 (grid=1287)
# 172 of 301 (grid=1151)
# 173 of 301 (grid=1292)
# 174 of 301 (grid=781)
# 175 of 301 (grid=1294)
# 176 of 301 (grid=1295)
# 177 of 301 (grid=1296)
# 178 of 301 (grid=216)
# 179 of 301 (grid=1298)
# 180 of 301 (grid=1155)
# 181 of 301 (grid=1070)
# 182 of 301 (grid=1302)
# 183 of 301 (grid=281)
# 184 of 301 (grid=1306)
# 185 of 301 (grid=796)
# 186 of 301 (grid=285)
# 187 of 301 (grid=1311)
# 188 of 301 (grid=288)
# 189 of 301 (grid=1313)
# 190 of 301 (grid=1314)
# 191 of 301 (grid=731)
# 192 of 301 (grid=1319)
# 193 of 301 (grid=1321)
# 194 of 301 (grid=814)
# 195 of 301 (grid=1245)
# 196 of 301 (grid=1328)
# 197 of 301 (grid=307)
# 198 of 301 (grid=1332)
# 199 of 301 (grid=309)
# 200 of 301 (grid=825)
# 201 of 301 (grid=315)
# 202 of 301 (grid=319)
# 203 of 301 (grid=832)
# 204 of 301 (grid=322)
# 205 of 301 (grid=323)
# 206 of 301 (grid=1348)
# 207 of 301 (grid=838)
# 208 of 301 (grid=993)
# 209 of 301 (grid=840)
# 210 of 301 (grid=329)
# 211 of 301 (grid=1355)
# 212 of 301 (grid=844)
# 213 of 301 (grid=845)
# 214 of 301 (grid=1358)
# 215 of 301 (grid=1359)
# 216 of 301 (grid=343)
# 217 of 301 (grid=717)
# 218 of 301 (grid=143)
# 219 of 301 (grid=1372)
# 220 of 301 (grid=349)
# 221 of 301 (grid=1374)
# 222 of 301 (grid=182)
# 223 of 301 (grid=864)
# 224 of 301 (grid=866)
# 225 of 301 (grid=867)
# 226 of 301 (grid=357)
# 227 of 301 (grid=145)
# 228 of 301 (grid=362)
# 229 of 301 (grid=364)
# 230 of 301 (grid=365)
# 231 of 301 (grid=232)
# 232 of 301 (grid=371)
# 233 of 301 (grid=372)
# 234 of 301 (grid=885)
# 235 of 301 (grid=375)
# 236 of 301 (grid=381)
# 237 of 301 (grid=895)
# 238 of 301 (grid=881)
# 239 of 301 (grid=900)
# 240 of 301 (grid=390)
# 241 of 301 (grid=904)
# 242 of 301 (grid=906)
# 243 of 301 (grid=1175)
# 244 of 301 (grid=354)
# 245 of 301 (grid=398)
# 246 of 301 (grid=749)
# 247 of 301 (grid=401)
# 248 of 301 (grid=402)
# 249 of 301 (grid=916)
# 250 of 301 (grid=409)
# 251 of 301 (grid=324)
# 252 of 301 (grid=923)
# 253 of 301 (grid=928)
# 254 of 301 (grid=417)
# 255 of 301 (grid=411)
# 256 of 301 (grid=326)
# 257 of 301 (grid=422)
# 258 of 301 (grid=241)
# 259 of 301 (grid=424)
# 260 of 301 (grid=937)
# 261 of 301 (grid=939)
# 262 of 301 (grid=669)
# 263 of 301 (grid=944)
# 264 of 301 (grid=433)
# 265 of 301 (grid=243)
# 266 of 301 (grid=439)
# 267 of 301 (grid=442)
# 268 of 301 (grid=444)
# 269 of 301 (grid=445)
# 270 of 301 (grid=958)
# 271 of 301 (grid=449)
# 272 of 301 (grid=450)
# 273 of 301 (grid=1099)
# 274 of 301 (grid=452)
# 275 of 301 (grid=1185)
# 276 of 301 (grid=457)
# 277 of 301 (grid=1271)
# 278 of 301 (grid=461)
# 279 of 301 (grid=974)
# 280 of 301 (grid=977)
# 281 of 301 (grid=979)
# 282 of 301 (grid=980)
# 283 of 301 (grid=846)
# 284 of 301 (grid=982)
# 285 of 301 (grid=983)
# 286 of 301 (grid=985)
# 287 of 301 (grid=986)
# 288 of 301 (grid=933)
# 289 of 301 (grid=480)
# 290 of 301 (grid=592)
# 291 of 301 (grid=1275)
# 292 of 301 (grid=1002)
# 293 of 301 (grid=491)
# 294 of 301 (grid=493)
# 295 of 301 (grid=1007)
# 296 of 301 (grid=168)
# 297 of 301 (grid=1012)
# 298 of 301 (grid=502)
# 299 of 301 (grid=1020)
# 300 of 301 (grid=801)
# 301 of 301 (grid=510)

# %% [markdown]
# This data is complementary to the last one, but it will search by keywords instead of type. This part will search at any information gathered by google.

# %%
#types=types_accepted+['supermarket']

### To Print results
prints=0

i=1
for grid in grids_data:
    print "%d of 301 (grid=%d)" %(i,grid)
    i+=1
#for grid in [1020]:
    ### First Step Search
    for typ in types_accepted:
        #print typ
        ### First 20 results
        res1=google_places.nearby_search(lat_lng=grids_data[grid],radius=100,keyword=typ)
        # For more than 20 results
        save_result(res1,prints)
        try:
            res2 = google_places.nearby_search(pagetoken=res1.next_page_token)
            save_result(res2,prints)
            try:
                res3 = google_places.nearby_search(pagetoken=res2.next_page_token)
                save_result(res3,prints)
                try:
                    res4 = google_places.nearby_search(pagetoken=res3.next_page_token)
                    save_result(res4,prints)
                except:
                    pass    
            except:
                pass
        except:
            pass
# Out:
# 1 of 301 (grid=1)
# 2 of 301 (grid=683)
# 3 of 301 (grid=4)
# 4 of 301 (grid=6)
# 5 of 301 (grid=290)
# 6 of 301 (grid=273)
# 7 of 301 (grid=525)
# 8 of 301 (grid=526)
# 9 of 301 (grid=173)
# 10 of 301 (grid=17)
# 11 of 301 (grid=1042)
# 12 of 301 (grid=515)
# 13 of 301 (grid=529)
# 14 of 301 (grid=23)
# 15 of 301 (grid=1049)
# 16 of 301 (grid=538)
# 17 of 301 (grid=1052)
# 18 of 301 (grid=1054)
# 19 of 301 (grid=543)
# 20 of 301 (grid=32)
# 21 of 301 (grid=474)
# 22 of 301 (grid=1058)
# 23 of 301 (grid=35)
# 24 of 301 (grid=1062)
# 25 of 301 (grid=1063)
# 26 of 301 (grid=553)
# 27 of 301 (grid=42)
# 28 of 301 (grid=555)
# 29 of 301 (grid=1069)
# 30 of 301 (grid=558)
# 31 of 301 (grid=1071)
# 32 of 301 (grid=560)
# 33 of 301 (grid=49)
# 34 of 301 (grid=947)
# 35 of 301 (grid=862)
# 36 of 301 (grid=568)
# 37 of 301 (grid=1082)
# 38 of 301 (grid=1127)
# 39 of 301 (grid=63)
# 40 of 301 (grid=64)
# 41 of 301 (grid=1089)
# 42 of 301 (grid=331)
# 43 of 301 (grid=69)
# 44 of 301 (grid=584)
# 45 of 301 (grid=587)
# 46 of 301 (grid=588)
# 47 of 301 (grid=589)
# 48 of 301 (grid=78)
# 49 of 301 (grid=1104)
# 50 of 301 (grid=1107)
# 51 of 301 (grid=84)
# 52 of 301 (grid=270)
# 53 of 301 (grid=86)
# 54 of 301 (grid=1111)
# 55 of 301 (grid=601)
# 56 of 301 (grid=1114)
# 57 of 301 (grid=603)
# 58 of 301 (grid=395)
# 59 of 301 (grid=93)
# 60 of 301 (grid=606)
# 61 of 301 (grid=471)
# 62 of 301 (grid=1124)
# 63 of 301 (grid=615)
# 64 of 301 (grid=1131)
# 65 of 301 (grid=108)
# 66 of 301 (grid=274)
# 67 of 301 (grid=1134)
# 68 of 301 (grid=701)
# 69 of 301 (grid=624)
# 70 of 301 (grid=113)
# 71 of 301 (grid=1138)
# 72 of 301 (grid=627)
# 73 of 301 (grid=1140)
# 74 of 301 (grid=629)
# 75 of 301 (grid=118)
# 76 of 301 (grid=1143)
# 77 of 301 (grid=1145)
# 78 of 301 (grid=634)
# 79 of 301 (grid=123)
# 80 of 301 (grid=1149)
# 81 of 301 (grid=638)
# 82 of 301 (grid=127)
# 83 of 301 (grid=1368)
# 84 of 301 (grid=107)
# 85 of 301 (grid=647)
# 86 of 301 (grid=648)
# 87 of 301 (grid=655)
# 88 of 301 (grid=1169)
# 89 of 301 (grid=659)
# 90 of 301 (grid=661)
# 91 of 301 (grid=662)
# 92 of 301 (grid=25)
# 93 of 301 (grid=397)
# 94 of 301 (grid=153)
# 95 of 301 (grid=667)
# 96 of 301 (grid=1180)
# 97 of 301 (grid=1181)
# 98 of 301 (grid=159)
# 99 of 301 (grid=1136)
# 100 of 301 (grid=163)
# 101 of 301 (grid=164)
# 102 of 301 (grid=198)
# 103 of 301 (grid=497)
# 104 of 301 (grid=167)
# 105 of 301 (grid=1192)
# 106 of 301 (grid=169)
# 107 of 301 (grid=682)
# 108 of 301 (grid=1195)
# 109 of 301 (grid=626)
# 110 of 301 (grid=686)
# 111 of 301 (grid=687)
# 112 of 301 (grid=712)
# 113 of 301 (grid=1202)
# 114 of 301 (grid=1139)
# 115 of 301 (grid=1206)
# 116 of 301 (grid=1207)
# 117 of 301 (grid=347)
# 118 of 301 (grid=799)
# 119 of 301 (grid=1212)
# 120 of 301 (grid=1213)
# 121 of 301 (grid=702)
# 122 of 301 (grid=703)
# 123 of 301 (grid=707)
# 124 of 301 (grid=710)
# 125 of 301 (grid=199)
# 126 of 301 (grid=1224)
# 127 of 301 (grid=1225)
# 128 of 301 (grid=859)
# 129 of 301 (grid=1227)
# 130 of 301 (grid=1228)
# 131 of 301 (grid=34)
# 132 of 301 (grid=206)
# 133 of 301 (grid=1231)
# 134 of 301 (grid=208)
# 135 of 301 (grid=722)
# 136 of 301 (grid=724)
# 137 of 301 (grid=462)
# 138 of 301 (grid=726)
# 139 of 301 (grid=215)
# 140 of 301 (grid=1240)
# 141 of 301 (grid=1241)
# 142 of 301 (grid=1371)
# 143 of 301 (grid=719)
# 144 of 301 (grid=732)
# 145 of 301 (grid=1146)
# 146 of 301 (grid=1248)
# 147 of 301 (grid=226)
# 148 of 301 (grid=1251)
# 149 of 301 (grid=741)
# 150 of 301 (grid=230)
# 151 of 301 (grid=178)
# 152 of 301 (grid=744)
# 153 of 301 (grid=235)
# 154 of 301 (grid=236)
# 155 of 301 (grid=210)
# 156 of 301 (grid=1265)
# 157 of 301 (grid=755)
# 158 of 301 (grid=244)
# 159 of 301 (grid=1150)
# 160 of 301 (grid=1270)
# 161 of 301 (grid=41)
# 162 of 301 (grid=468)
# 163 of 301 (grid=639)
# 164 of 301 (grid=765)
# 165 of 301 (grid=255)
# 166 of 301 (grid=768)
# 167 of 301 (grid=769)
# 168 of 301 (grid=771)
# 169 of 301 (grid=470)
# 170 of 301 (grid=262)
# 171 of 301 (grid=1287)
# 172 of 301 (grid=1151)
# 173 of 301 (grid=1292)
# 174 of 301 (grid=781)
# 175 of 301 (grid=1294)
# 176 of 301 (grid=1295)
# 177 of 301 (grid=1296)
# 178 of 301 (grid=216)
# 179 of 301 (grid=1298)
# 180 of 301 (grid=1155)
# 181 of 301 (grid=1070)
# 182 of 301 (grid=1302)
# 183 of 301 (grid=281)
# 184 of 301 (grid=1306)
# 185 of 301 (grid=796)
# 186 of 301 (grid=285)
# 187 of 301 (grid=1311)
# 188 of 301 (grid=288)
# 189 of 301 (grid=1313)
# 190 of 301 (grid=1314)
# 191 of 301 (grid=731)
# 192 of 301 (grid=1319)
# 193 of 301 (grid=1321)
# 194 of 301 (grid=814)
# 195 of 301 (grid=1245)
# 196 of 301 (grid=1328)
# 197 of 301 (grid=307)
# 198 of 301 (grid=1332)
# 199 of 301 (grid=309)
# 200 of 301 (grid=825)
# 201 of 301 (grid=315)
# 202 of 301 (grid=319)
# 203 of 301 (grid=832)
# 204 of 301 (grid=322)
# 205 of 301 (grid=323)
# 206 of 301 (grid=1348)
# 207 of 301 (grid=838)
# 208 of 301 (grid=993)
# 209 of 301 (grid=840)
# 210 of 301 (grid=329)
# 211 of 301 (grid=1355)
# 212 of 301 (grid=844)
# 213 of 301 (grid=845)
# 214 of 301 (grid=1358)
# 215 of 301 (grid=1359)
# 216 of 301 (grid=343)
# 217 of 301 (grid=717)
# 218 of 301 (grid=143)
# 219 of 301 (grid=1372)
# 220 of 301 (grid=349)
# 221 of 301 (grid=1374)
# 222 of 301 (grid=182)
# 223 of 301 (grid=864)
# 224 of 301 (grid=866)
# 225 of 301 (grid=867)
# 226 of 301 (grid=357)
# 227 of 301 (grid=145)
# 228 of 301 (grid=362)
# 229 of 301 (grid=364)
# 230 of 301 (grid=365)
# 231 of 301 (grid=232)
# 232 of 301 (grid=371)
# 233 of 301 (grid=372)
# 234 of 301 (grid=885)
# 235 of 301 (grid=375)
# 236 of 301 (grid=381)
# 237 of 301 (grid=895)
# 238 of 301 (grid=881)
# 239 of 301 (grid=900)
# 240 of 301 (grid=390)
# 241 of 301 (grid=904)
# 242 of 301 (grid=906)
# 243 of 301 (grid=1175)
# 244 of 301 (grid=354)
# 245 of 301 (grid=398)
# 246 of 301 (grid=749)
# 247 of 301 (grid=401)
# 248 of 301 (grid=402)
# 249 of 301 (grid=916)
# 250 of 301 (grid=409)
# 251 of 301 (grid=324)
# 252 of 301 (grid=923)
# 253 of 301 (grid=928)
# 254 of 301 (grid=417)
# 255 of 301 (grid=411)
# 256 of 301 (grid=326)
# 257 of 301 (grid=422)
# 258 of 301 (grid=241)
# 259 of 301 (grid=424)
# 260 of 301 (grid=937)
# 261 of 301 (grid=939)
# 262 of 301 (grid=669)
# 263 of 301 (grid=944)
# 264 of 301 (grid=433)
# 265 of 301 (grid=243)
# 266 of 301 (grid=439)
# 267 of 301 (grid=442)
# 268 of 301 (grid=444)
# 269 of 301 (grid=445)
# 270 of 301 (grid=958)
# 271 of 301 (grid=449)
# 272 of 301 (grid=450)
# 273 of 301 (grid=1099)
# 274 of 301 (grid=452)
# 275 of 301 (grid=1185)
# 276 of 301 (grid=457)
# 277 of 301 (grid=1271)
# 278 of 301 (grid=461)
# 279 of 301 (grid=974)
# 280 of 301 (grid=977)
# 281 of 301 (grid=979)
# 282 of 301 (grid=980)
# 283 of 301 (grid=846)
# 284 of 301 (grid=982)
# 285 of 301 (grid=983)
# 286 of 301 (grid=985)
# 287 of 301 (grid=986)
# 288 of 301 (grid=933)
# 289 of 301 (grid=480)
# 290 of 301 (grid=592)
# 291 of 301 (grid=1275)
# 292 of 301 (grid=1002)
# 293 of 301 (grid=491)
# 294 of 301 (grid=493)
# 295 of 301 (grid=1007)
# 296 of 301 (grid=168)
# 297 of 301 (grid=1012)
# 298 of 301 (grid=502)
# 299 of 301 (grid=1020)
# 300 of 301 (grid=801)
# 301 of 301 (grid=510)

# %%
print len(places_flc)
# Out:
# 4573

# %% [markdown]
# ### Save RawData

# %% [markdown]
# Before classification, we save the entire data set.

# %%
import json
### Save
json = json.dumps(places_flc)
f = open("/Users/juancarlosmunoz/Dropbox/Obsogenic_Project/02_Output_DataBase/flc_rawresults_grids_13022018.json","w")
f.write(json)
f.close()

## Open
#file=open("/Users/juancarlosmunoz/Dropbox/Obsogenic_Project/flc_rawresults_grids.json", 'r')
#data = json.load(places_flc)

# %% [markdown]
# ## Facility List Coder in action: Classifying the places

# %% [markdown]
# Now, once all the places are gather using the two strategies, we now need to clean and classify then.

# %% [markdown]
# ### Clean Data Set

# %% [markdown]
# First we delete those establishments that will be excluded.

# %%
### First data
places_flc_cleaned={}

# Excluded Types
excluded_types=['health','finance','pharmacy','electrician','church','parking']
# Excluded Names (part of)
excluded_names=['parking']

#### First Step ---> Those in the excluded categories
for i in places_flc:
    ### Check for those with a excluded
    name=places_flc[i]['place_name'].lower().encode('utf-8').strip().split()
    if any(x in places_flc[i]['place_types'] for x in types_excluded):
        pass
    if any(x in name for x in excluded_names):
        pass
    else:
        places_flc_cleaned[i]=places_flc[i]

# %%
final_ds=[]
del_id=[]
## Step 1: Classification based on type of place
for place in places_flc_cleaned:
    ## Step 0 - Using Type
    if 'bakery' in places_flc_cleaned[place]['place_types']:
        sav_final(place,'harinas y derivados',final_ds)
        del_id.append(str(place))
        
    if any(x in places_flc_cleaned[place]['place_types'] for x in [u'grocery_or_supermarket',u'convenience_store']):
        sav_final(place,'establecimientos polivalentes',final_ds)
        del_id.append(str(place))
        
    if any(x in places_flc_cleaned[place]['place_types'] for x in [u'cafe',u'restaurant',u'meal_delivery',u'meal_takeaway',u'bar']):
        sav_final(place,'comidas preparadas',final_ds)
        del_id.append(str(place))

# %%
## Step 2: Classification based on names
for place in places_flc_cleaned:
    if place not in del_id:
        for cat in categ_est:
            for word in categ_est[cat]:
                if word!='bar':
                    w_test=str(places_flc_cleaned[place]['place_name'].encode('utf-8')).lower()
                    q_test="^.*"+word+".*$"
                    query=re.search(q_test,w_test)
                    if query is not None:
                        sav_final(place,cat,final_ds)
                        del_id.append(str(place))
                        print places_flc_cleaned[place]['place_name']

                #print query
                #try:
                #    print "----------"
                #    print len(query.group(0))
                #    print "----------"
                #except:
                #    pass
                #if query.group(0) is not NULL:
                #    print "HELLO" 
                # =str(palabras.cell(row=row, column=col).value).lower().strip().decode('ascii')
# Out:
# Carniceria La Pau
# Xurreria Rostisseria Jiménez
# Xurreria Rostisseria Jiménez
# LLEGUMS CUITS BLANCA
# Rostisseria K-pollo!
# Royal Fruitilandia
# Zoom Cafeteria Creperia
# Zoom Cafeteria Creperia
# Santa Supermercat
# Mataró Fruteria I Verdures
# Mataró Fruteria I Verdures
# Carniceria-Charcuteria Postigo
# Carniceria-Charcuteria Postigo
# Llaminadures Chupa - Chupi
# LA XARCUTERIA
# Ninafruits
# Supermercat I Alimentacio
# Can Serrat - Cansaladeria
# Peixateria Barbena
# Fornituras MB, S.L.
# Frutería Rodríguez
# La Boutique De La Fruita
# Granja Leunam Gelateria Croissanteria
# Maquinaria para panaderias Tecnotradegroup
# Fruites I Alimentación
# Fruites I Alimentación
# Churreria López
# Carnicería Manuel Oliva
# Carnisseria Alimentació Larache
# Fruiteria La Maduixa
# Fruiteria La Maduixa
# Golosinas
# Carnisseria Najem
# Gelateria, Gofreria i Futbolins Can Pitu
# Carnisseria - Xarcuteria Lopez & Hidaigo
# Carnisseria - Xarcuteria Lopez & Hidaigo
# Carnisseria Alimentacio
# Embutidos MBM
# Antonio Churreria
# Carnisseria Alimentaçió Fruites Verdures
# Carnisseria Alimentaçió Fruites Verdures
# Carnisseria Alimentaçió Fruites Verdures
# Carnisseria Alimentaçió Fruites Verdures
# Royal Fruitelandia
# L MERCADO DE LAS OPORTUNIDADES
# Peixateria Montse
# embutidosyjamonesibericos
# La Fornenca
# Embutidos Llobet SA
# Can Grau Verdures i Hortalisses
# Can Grau Verdures i Hortalisses
# La Formatgeria Mataró
# La Formatgeria Mataró
# Carnisseria Galán
# Granja Piollastres A L'ast Xurreria
# Supermercat
# Parc Central Supermercat
# Grup Sucre Preust
# Frutes I Verdures Choulli
# Fruites I Verdures
# Fruites I Verdures
# Fruites I Verdures
# Fruits Montull I Fills SL
# Mercat de la Plaça de Cuba
# Peixateria Codina
# Parra Fruits
# Mellado Almohalla Gregorio
# Viumar Peixateria
# Tot En Alimentació Supermercat Llaminadures
# Tot En Alimentació Supermercat Llaminadures
# Oficinas Pizzeria Carlos
# Xurreria Rosita
# Apple Fruits
# Carnicería Islámica Rif
# Carns Torrent
# Ben Fet Gelateria
# El Petit Mercat
# Forn Del Llibre
# Gombo Supermercados SL
# Mestres Forners des de 1903
# California Jeans S Cv P
# Paper i Sucre
# Carns Asturgó
# Dani Supermercat
# charcuteria Aurora
# Carnisseria Marti Riu
# Mercado
# Peixateria M Rosa
# Forni Fil SL
# Fornituras Mataro SL
# Consumelojusto.Com
# Al Hilal Carniceria
# Fruites Mini Supermercat Verdures
# Fruites Mini Supermercat Verdures
# Fruites Mini Supermercat Verdures
# Fruites Mini Supermercat Verdures
# Bread & Onion
# Carnisseria Charcuteria
# Carnisseria Charcuteria
# Pescaderia Llanesmar
# Carnisseria Cristina Pau
# Carnisseria Rodón
# La fruiteria de Mon Viu
# La fruiteria de Mon Viu
# LIVAROT FORMATGES DEL MÓN
# Mataro Mercado Pescado
# Mundo Carnes
# Aliza I Mawi Supermercat
# Gelateria
# Vilas Melero Josep
# Dolç I Sec Cafés Muset
# Carniceria Paquita E Hijos SL
# rostisseria pit i cuixa 2 mataro
# Carniceria halal Market Yassin
# Francisco Palau del Mas Armella
# Fruites Verdures Ana
# Fruites Verdures Ana
# Fruites Verdures Ana
# Carnisseria Galán
# Fruit Sa2pe S.L.
# Nugafruits Serveis de Distribució Sa
# Trady's Supermercats
# Xurreria - Rostisseria Navas
# Xurreria - Rostisseria Navas
# Turrones Y Mazapanes Los Extremeños
# Supermercat Chuches
# Carniceria Y Polleria Marathon
# Carniceria JUANJO
# Charcuteria Moreno SL
# Calzados Melero
# Gemma Suñé Gamell
# Peixateria Salva Solís
# Fruiteria Aoxin
# Fruiteria Aoxin
# Molina Fornitures SL
# Xarcuteries Miguel I Begoña

# %%
for place in places_flc_cleaned:
    if place not in del_id:
        if 'food' in places_flc_cleaned[place]['place_types']:
            pass
        else:
            print places_flc_cleaned[place]['place_name'],places_flc_cleaned[place]['place_types']
# Out:
# BAXI Servicio Técnico Oficial [u'point_of_interest', u'establishment']
# TABASCO Textil Hogar [u'point_of_interest', u'establishment']
# Industrial Gil Ba S L [u'point_of_interest', u'establishment']
# Calmespai Fisioteràpia [u'physiotherapist', u'health', u'point_of_interest', u'establishment']
# Isabel Espinosa Peláez [u'dentist', u'health', u'point_of_interest', u'establishment']
# H&M (C.C. Mataró Parc) [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Casas - Moventis [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Inmopaca [u'point_of_interest', u'establishment']
# Micromidi SL [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Basar Asiatic [u'store', u'point_of_interest', u'establishment']
# Salesians Sant Antoni De Pàdua [u'point_of_interest', u'establishment']
# Zhou, Zuochong [u'point_of_interest', u'establishment']
# COCINAS.COM Centrasa [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Dendromon [u'point_of_interest', u'establishment']
# Pisos I Àtics En Venda [u'real_estate_agency', u'point_of_interest', u'establishment']
# Smb Suport Legal [u'point_of_interest', u'establishment']
# Unipresalud [u'insurance_agency', u'point_of_interest', u'establishment']
# Ducable Libros [u'book_store', u'store', u'point_of_interest', u'establishment']
# Can Palauet [u'art_gallery', u'point_of_interest', u'establishment']
# Don Ocasio Segundamano [u'store', u'point_of_interest', u'establishment']
# TRANS-BALTAR (Bernat Rodríguez Aránega) [u'moving_company', u'point_of_interest', u'establishment']
# C Nour Agéncia de Viatges [u'travel_agency', u'point_of_interest', u'establishment']
# Node [u'point_of_interest', u'establishment']
# Tellmebye S.L. [u'point_of_interest', u'establishment']
# Punt Eggli, S.L. [u'point_of_interest', u'establishment']
# CaixaBank [u'bank', u'finance', u'point_of_interest', u'establishment']
# Peluquería Aura [u'beauty_salon', u'point_of_interest', u'establishment']
# Montalt [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Lepant Centre Cos I Ment [u'point_of_interest', u'establishment']
# Estanc Tabacs nº 5 [u'store', u'point_of_interest', u'establishment']
# Ximenes Òptics [u'store', u'health', u'point_of_interest', u'establishment']
# Montessori Vivo [u'store', u'point_of_interest', u'establishment']
# Associació Esportiva Plá D'En Boet [u'point_of_interest', u'establishment']
# Toldos A.Mota [u'point_of_interest', u'establishment']
# Promocions Urbanistiques de Mataró S.A. [u'real_estate_agency', u'point_of_interest', u'establishment']
# Antonio Martínez Galera [u'point_of_interest', u'establishment']
# Masaje Oriental [u'health', u'point_of_interest', u'establishment']
# Batcova [u'point_of_interest', u'establishment']
# Isa [u'hair_care', u'point_of_interest', u'establishment']
# Monte Import Textil S.L. [u'point_of_interest', u'establishment']
# FACTORYGRAF [u'point_of_interest', u'establishment']
# La Rosa d´Alexandria Cortines Mataró [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Marlabal SL [u'point_of_interest', u'establishment']
# Cajero automático Caixabank [u'atm', u'finance', u'point_of_interest', u'establishment']
# Centre de Persones Sordes de Maresme a Mataró [u'point_of_interest', u'establishment']
# A la teva mida [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# ohma! Barcelona [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Autoescola Comarca [u'school', u'point_of_interest', u'establishment']
# Construvert [u'point_of_interest', u'establishment']
# 9/25 Llibres d'Oferta [u'book_store', u'store', u'point_of_interest', u'establishment']
# Juan Antonio Quintana Romero [u'point_of_interest', u'establishment']
# Estudi Foto WK [u'point_of_interest', u'establishment']
# Dent Clinic [u'dentist', u'health', u'point_of_interest', u'establishment']
# Vanessa Linares [u'art_gallery', u'point_of_interest', u'establishment']
# Cat 5127 S L [u'point_of_interest', u'establishment']
# Instal·lacions Ismax s.l. [u'electrician', u'plumber', u'home_goods_store', u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Delta Serveis Socio Sanitaris S.L [u'point_of_interest', u'establishment']
# Expert [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Leader Car European Car Suppliers [u'point_of_interest', u'establishment']
# Slä Arquitectes [u'point_of_interest', u'establishment']
# Hallotex S L [u'point_of_interest', u'establishment']
# Rituals [u'store', u'point_of_interest', u'establishment']
# Guevara Rodríguez, G. [u'store', u'point_of_interest', u'establishment']
# Promocions Urbanistiques de Mataró S.A. [u'real_estate_agency', u'point_of_interest', u'establishment']
# JORDI TRENS JOIERS [u'jewelry_store', u'store', u'point_of_interest', u'establishment']
# Encama [u'point_of_interest', u'establishment']
# Planxa i Pintura MARCH [u'car_repair', u'point_of_interest', u'establishment']
# Museo Arxiu Santa María Centre D Estudis Locals de Mataró [u'store', u'point_of_interest', u'establishment']
# Elbair Abdeslam [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# TXT VERETEX S.L. [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Copistería Castellà [u'point_of_interest', u'establishment']
# Re - Read Mataró [u'book_store', u'store', u'point_of_interest', u'establishment']
# Doña Tela [u'store', u'point_of_interest', u'establishment']
# Cambra de Comerç de Barcelona (Delegació al Maresme) [u'point_of_interest', u'establishment']
# Grup Gamma [u'point_of_interest', u'establishment']
# Denilo Alquieler De Barcos [u'point_of_interest', u'establishment']
# Cgo Centre Ginecològic I Obstètric [u'doctor', u'health', u'point_of_interest', u'establishment']
# Farmacia Carretera de Mata 43 [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# Moquetes Roba De Casa [u'point_of_interest', u'establishment']
# Ràdio Taxi Mataró [u'point_of_interest', u'establishment']
# Avenida [u'point_of_interest', u'establishment']
# balada papereria [u'store', u'point_of_interest', u'establishment']
# Anytime Fitness Mataró [u'gym', u'health', u'point_of_interest', u'establishment']
# marcllacuna [u'point_of_interest', u'establishment']
# Totseriman [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# guum barcelona [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# AGH Asesoría y Gestiones Hernández [u'accounting', u'finance', u'point_of_interest', u'establishment']
# Orthogar S.L. [u'real_estate_agency', u'point_of_interest', u'establishment']
# L' Eixida [u'point_of_interest', u'establishment']
# Cableuropa S A U [u'point_of_interest', u'establishment']
# Crazylove tienda erótica / Sexshop [u'shopping_mall', u'store', u'point_of_interest', u'establishment']
# Saltoki Mataró [u'store', u'point_of_interest', u'establishment']
# Rda. Barceló [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Fisbert Lare SL FÀBRICA TÈXTIL [u'point_of_interest', u'establishment']
# Discolandia 2.0 [u'point_of_interest', u'establishment']
# Portactil Sl [u'point_of_interest', u'establishment']
# Laminas Solares Daijo [u'car_repair', u'point_of_interest', u'establishment']
# Assessoria L´esplanada [u'finance', u'point_of_interest', u'establishment']
# INTERNET LEVEL ELEVEN SL [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Montesorri vivo [u'store', u'point_of_interest', u'establishment']
# boluda.com [u'point_of_interest', u'establishment']
# Margarita Busqui Llabrés [u'point_of_interest', u'establishment']
# Quirzmont 94 Sl [u'general_contractor', u'point_of_interest', u'establishment']
# Watly [u'point_of_interest', u'establishment']
# Mataró Marina Barcelona [u'point_of_interest', u'establishment']
# ESED [u'point_of_interest', u'establishment']
# Advocats Mataro / Jordi Puigvert Terra [u'point_of_interest', u'establishment']
# adidas Store Mataró [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Fashion Prints Barcelona [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Dòria Llibres [u'book_store', u'store', u'point_of_interest', u'establishment']
# Silvia Roig Serrano [u'point_of_interest', u'establishment']
# Rassa - Beauty in Essence [u'beauty_salon', u'hair_care', u'spa', u'store', u'lodging', u'health', u'point_of_interest', u'establishment']
# Rehabilitaciones Pinvert [u'point_of_interest', u'establishment']
# Como Mataró S L [u'store', u'point_of_interest', u'establishment']
# Farm Frites S.A. [u'point_of_interest', u'establishment']
# Pedro Durán [u'point_of_interest', u'establishment']
# Ayola 3 SL [u'point_of_interest', u'establishment']
# Silex Gestión [u'finance', u'point_of_interest', u'establishment']
# Transit Mataro [u'furniture_store', u'painter', u'home_goods_store', u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Moldumat [u'store', u'point_of_interest', u'establishment']
# MantenimientoTecnico [u'point_of_interest', u'establishment']
# boboli [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# José Subirana Ribera [u'point_of_interest', u'establishment']
# Ronetsa Telecom, Sl [u'electrician', u'point_of_interest', u'establishment']
# Roque Gómez, Scp [u'electrician', u'point_of_interest', u'establishment']
# Parròquia de Nostra Senyora de l'Esperança [u'church', u'place_of_worship', u'point_of_interest', u'establishment']
# Pelegrí Abogados [u'lawyer', u'point_of_interest', u'establishment']
# Sedano Salvador, M. [u'point_of_interest', u'establishment']
# FOTOCINE VIADA [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Escola Freta [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# I De N Fabricación Propia [u'point_of_interest', u'establishment']
# Antoni Sánchez García [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Sent Actiu [u'health', u'point_of_interest', u'establishment']
# maletasdarbra [u'shopping_mall', u'point_of_interest', u'establishment']
# Herbodiet [u'store', u'point_of_interest', u'establishment']
# Onveló Cycling [u'bicycle_store', u'store', u'point_of_interest', u'establishment']
# Different'$ Moda [u'store', u'point_of_interest', u'establishment']
# Consultorio de Podologia [u'doctor', u'health', u'point_of_interest', u'establishment']
# ACSIS psicomotricitat [u'health', u'point_of_interest', u'establishment']
# Suministros A. Trullas S.A. [u'point_of_interest', u'establishment']
# Velòdrom Mataró [u'point_of_interest', u'establishment']
# Sant Simó [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# EDRA SOLUCIONES SL [u'point_of_interest', u'establishment']
# Nimar Aplicaciones S.L. [u'general_contractor', u'point_of_interest', u'establishment']
# Parc La Llàntia [u'transit_station', u'point_of_interest', u'establishment']
# Bureau Veritas Inversiones [u'real_estate_agency', u'point_of_interest', u'establishment']
# MALETAS DARBRA [u'store', u'point_of_interest', u'establishment']
# ESTANC BLASCO [u'store', u'point_of_interest', u'establishment']
# Musical Mataro [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Parc La Llàntia [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# El Racó de la Llar [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Hyla Ibérica Mataró [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Mataró Móvil [u'store', u'point_of_interest', u'establishment']
# Makerspace Mataró [u'school', u'point_of_interest', u'establishment']
# Xavier Clavell Pons [u'bicycle_store', u'store', u'point_of_interest', u'establishment']
# Podomat [u'doctor', u'health', u'point_of_interest', u'establishment']
# Santa Marta Lloguers [u'real_estate_agency', u'point_of_interest', u'establishment']
# Asociación de Cabezas de Familia y Vecinos San Juan Bosco [u'point_of_interest', u'establishment']
# Jumping Extreme Mataró [u'gym', u'health', u'point_of_interest', u'establishment']
# Reconeixament mèdic Gemma [u'hospital', u'point_of_interest', u'establishment']
# VallasPVC.es [u'point_of_interest', u'establishment']
# Corporación Dermoestetica S A [u'point_of_interest', u'establishment']
# MásMóvil Mataró Centre [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Centre Geriàtric Cerdanyola SL [u'point_of_interest', u'establishment']
# Equimar SCCL [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# IFS - Centre Mèdic [u'doctor', u'health', u'point_of_interest', u'establishment']
# agcm plastic solutions [u'point_of_interest', u'establishment']
# Pavid Net S L [u'point_of_interest', u'establishment']
# ESPAI CLINIC MATARO [u'beauty_salon', u'hair_care', u'spa', u'health', u'point_of_interest', u'establishment']
# Springfield - SPF Man & Woman [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# ZAMORA shop [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# LCR Transportes [u'point_of_interest', u'establishment']
# Vinizius [u'night_club', u'point_of_interest', u'establishment']
# GRAFICAS ARGRA [u'store', u'point_of_interest', u'establishment']
# Josmigmar-Pum S L [u'point_of_interest', u'establishment']
# kuyku [u'general_contractor', u'point_of_interest', u'establishment']
# Chupi Guay [u'point_of_interest', u'establishment']
# Carbon Bike repairs [u'point_of_interest', u'establishment']
# KINTSUGI - Emocions i Salut [u'health', u'point_of_interest', u'establishment']
# Tecnimoto [u'car_repair', u'point_of_interest', u'establishment']
# ASPY Prevención [u'point_of_interest', u'establishment']
# F Cuba [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# Font&Roca [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Jorge López Pérez, Advocat [u'lawyer', u'point_of_interest', u'establishment']
# Vidres Orga [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Containers Mataró [u'point_of_interest', u'establishment']
# Mapfre [u'insurance_agency', u'finance', u'health', u'point_of_interest', u'establishment']
# Club Voleibol Mataró [u'gym', u'health', u'point_of_interest', u'establishment']
# MICRO-HOME [u'point_of_interest', u'establishment']
# SANIMAMP 2005 [u'point_of_interest', u'establishment']
# Central Park Mataró S L [u'point_of_interest', u'establishment']
# Fran Paper 2000 S L [u'store', u'point_of_interest', u'establishment']
# Edificio El Turó [u'point_of_interest', u'establishment']
# CSI Informatica de Gestio SL [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# TRAVEL SPORTS Torneos de Futbol [u'point_of_interest', u'establishment']
# Can Mercé [u'point_of_interest', u'establishment']
# DGROUPMATARO [u'place_of_worship', u'point_of_interest', u'establishment']
# Diamonds Moda [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Peluts de Mataro peluqueria canina y felina [u'pet_store', u'store', u'point_of_interest', u'establishment']
# ÀTIC Coworking Business Center [u'point_of_interest', u'establishment']
# Bcn Seo Consulting - Consultoría SEO [u'point_of_interest', u'establishment']
# Degustació [u'point_of_interest', u'establishment']
# Audio instruments low cost [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# INVENNTIA [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Duplicat Claus Mataró [u'point_of_interest', u'establishment']
# Luna Barcelona [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Manufacturas de la Etiqueta [u'point_of_interest', u'establishment']
# Tsuk Japones [u'point_of_interest', u'establishment']
# Plá del Boet [u'car_repair', u'point_of_interest', u'establishment']
# Comon Tecnología I Serveis ,S.L [u'point_of_interest', u'establishment']
# Coworking Point [u'point_of_interest', u'establishment']
# Tabacs [u'store', u'point_of_interest', u'establishment']
# MARC LIGOS STUDIO [u'general_contractor', u'point_of_interest', u'establishment']
# Marlo's Zapatería [u'shopping_mall', u'point_of_interest', u'establishment']
# Teatre Monumental [u'movie_theater', u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Gret Mai S L [u'general_contractor', u'point_of_interest', u'establishment']
# Administrador de Finques [u'real_estate_agency', u'point_of_interest', u'establishment']
# Instituto Municipal de Promoción Económica Impem [u'local_government_office', u'finance', u'point_of_interest', u'establishment']
# Brodats Sara [u'point_of_interest', u'establishment']
# Rios Running [u'store', u'point_of_interest', u'establishment']
# Calçats RS [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# Finques Andreu [u'point_of_interest', u'establishment']
# FYR LEGAL [u'point_of_interest', u'establishment']
# Sport Maillot [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Peluqueria Laura [u'beauty_salon', u'point_of_interest', u'establishment']
# VP Audio Profesional [u'point_of_interest', u'establishment']
# Labor Invicta Sl [u'store', u'point_of_interest', u'establishment']
# Locutori Public [u'point_of_interest', u'establishment']
# Peluquería Onze [u'hair_care', u'point_of_interest', u'establishment']
# Calma House [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Instituto Ataraxia SL [u'health', u'point_of_interest', u'establishment']
# IAT España SA [u'point_of_interest', u'establishment']
# Recanvis Grup 5, S.A.L. [u'car_repair', u'store', u'point_of_interest', u'establishment']
# Peluquería Apolonia i Antonio [u'beauty_salon', u'hair_care', u'point_of_interest', u'establishment']
# Mobles Eslar [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# e-mas [u'finance', u'point_of_interest', u'establishment']
# Neumaticos Torres [u'car_repair', u'store', u'point_of_interest', u'establishment']
# Auto Escuelas Monfen [u'point_of_interest', u'establishment']
# Cajero automático Caixabank [u'atm', u'finance', u'point_of_interest', u'establishment']
# Sant Valentí [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Associació Cannàbica The Green Way [u'point_of_interest', u'establishment']
# Josep Medina Ajates [u'point_of_interest', u'establishment']
# Perruqueria Isabel [u'hair_care', u'point_of_interest', u'establishment']
# Associació Síndrome d'Asperger del Maresme [u'point_of_interest', u'establishment']
# Dlimit [u'point_of_interest', u'establishment']
# Robreño Esperalba Y Puig SL [u'point_of_interest', u'establishment']
# Fetishxa [u'point_of_interest', u'establishment']
# Irlanda [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Chinese Store [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# DirCom Marketing SL [u'point_of_interest', u'establishment']
# Oficina Banco Santander [u'bank', u'atm', u'finance', u'point_of_interest', u'establishment']
# Fisioterapia Elisabet Villaronga [u'physiotherapist', u'health', u'point_of_interest', u'establishment']
# Colla Castellera Capgrossos de Mataró [u'point_of_interest', u'establishment']
# LUX360 [u'point_of_interest', u'establishment']
# Telefónica Telecomunicaciones Públicas [u'point_of_interest', u'establishment']
# Alimmenta, dietistas-nutricionistas [u'health', u'point_of_interest', u'establishment']
# MC Mutual [u'insurance_agency', u'point_of_interest', u'establishment']
# David Clapes López [u'point_of_interest', u'establishment']
# Leonart Motors [u'store', u'point_of_interest', u'establishment']
# City Locutorio [u'point_of_interest', u'establishment']
# Pca Procesos De Fluídos [u'point_of_interest', u'establishment']
# Fisioterapia Olga [u'physiotherapist', u'health', u'point_of_interest', u'establishment']
# ARQUITECTURA I.M. tecnics [u'point_of_interest', u'establishment']
# Garcia Perruquers [u'hair_care', u'point_of_interest', u'establishment']
# Turó de Cerdanyola [u'park', u'point_of_interest', u'establishment']
# Sports Tubkal [u'store', u'point_of_interest', u'establishment']
# Escola Freta [u'transit_station', u'point_of_interest', u'establishment']
# instituto de traumatología barcelona [u'point_of_interest', u'establishment']
# Crealo [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Magiccuin [u'point_of_interest', u'establishment']
# Plaça de Can Gassol [u'point_of_interest', u'establishment']
# El Taller del PC [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Bankia [u'bank', u'finance', u'point_of_interest', u'establishment']
# Mª DOLORS BARBARÀ ADVOCADA MATRIMONIALISTA - MATARÓ [u'lawyer', u'point_of_interest', u'establishment']
# Misioneras Inmaculada Concepción [u'point_of_interest', u'establishment']
# Pradas [u'point_of_interest', u'establishment']
# Perú [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# cristina lianes [u'point_of_interest', u'establishment']
# Elisa Cañestro - Arquitecto técnico [u'point_of_interest', u'establishment']
# PC MOTORS [u'car_repair', u'point_of_interest', u'establishment']
# Alberto Ramos Mendoza [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# alsamanela [u'point_of_interest', u'establishment']
# BIOVida Mataró [u'health', u'point_of_interest', u'establishment']
# Forum [u'point_of_interest', u'establishment']
# Anfregeda S.L [u'general_contractor', u'point_of_interest', u'establishment']
# PROMREGAL [u'point_of_interest', u'establishment']
# Singular Home 2000 S.L. [u'store', u'point_of_interest', u'establishment']
# Attitude [u'point_of_interest', u'establishment']
# Cabré Junqueras, serveis funeraris [u'funeral_home', u'point_of_interest', u'establishment']
# Construcciones Antonio Cruz [u'point_of_interest', u'establishment']
# natural freedom [u'store', u'point_of_interest', u'establishment']
# Marfran Sabateries [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# Tc Ebenistes S L [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Taller De Surf [u'point_of_interest', u'establishment']
# Fuente Plaza Italia [u'museum', u'point_of_interest', u'establishment']
# Roca Blanca [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Basar Oriental [u'store', u'point_of_interest', u'establishment']
# Brullet Serralers S.L. [u'point_of_interest', u'establishment']
# Lacoste [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Irvia Mataró [u'point_of_interest', u'establishment']
# gir 360 [u'point_of_interest', u'establishment']
# papereria-copisteria A quatre [u'store', u'point_of_interest', u'establishment']
# casa viva Mataró [u'home_goods_store', u'furniture_store', u'store', u'point_of_interest', u'establishment']
# IMPLANT PROTESIS DENTAL 2004 SL [u'store', u'health', u'point_of_interest', u'establishment']
# P.I. Can Negoci - Av. Molí de les Mateves [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Buzón de Correos [u'point_of_interest', u'establishment']
# Nef Redes Y Sistemas SL [u'electrician', u'point_of_interest', u'establishment']
# Juan Moreno Calvo [u'point_of_interest', u'establishment']
# SECRET BOX- Escape room Mataró [u'point_of_interest', u'establishment']
# Tapiceria y Toldos Toni [u'point_of_interest', u'establishment']
# Indigo nails spain+ [u'store', u'point_of_interest', u'establishment']
# Antonia González Camacho [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Suyty Ropa Sofisticada y Atrevida para Mujer [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Carpintería de Aluminio Iluro [u'general_contractor', u'point_of_interest', u'establishment']
# Vodafone [u'store', u'point_of_interest', u'establishment']
# arrels psicologia mataró [u'health', u'point_of_interest', u'establishment']
# Registro de la Propiedad de Mataró Nº 01 [u'lodging', u'point_of_interest', u'establishment']
# CaixaBank [u'bank', u'finance', u'point_of_interest', u'establishment']
# Espai Firal [u'point_of_interest', u'establishment']
# GLOBAL ENGLISH ACADÈMIA D´ANGLÈS [u'point_of_interest', u'establishment']
# New Resormccq 2008 S L [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Canastillas Universal Bebé [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Gráficas Igm [u'store', u'point_of_interest', u'establishment']
# Casal Municipal de la Gent Gran de Pla d'en Boet [u'point_of_interest', u'establishment']
# Elite [u'travel_agency', u'point_of_interest', u'establishment']
# Administración de Lotería N 1 [u'store', u'point_of_interest', u'establishment']
# Arquera Neteges [u'point_of_interest', u'establishment']
# Sopena & Associats [u'accounting', u'lawyer', u'finance', u'point_of_interest', u'establishment']
# Club Gimnàstic Mataró [u'point_of_interest', u'establishment']
# Mazidesigns [u'point_of_interest', u'establishment']
# Retols Greg [u'point_of_interest', u'establishment']
# ANUIMA Arquitectura y Construcción [u'general_contractor', u'point_of_interest', u'establishment']
# Cosmetica perfumes [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# b-Kover Mataró [u'store', u'point_of_interest', u'establishment']
# Ballenoil [u'gas_station', u'car_wash', u'point_of_interest', u'establishment']
# Gesoci S A [u'finance', u'point_of_interest', u'establishment']
# Bbva [u'bank', u'finance', u'point_of_interest', u'establishment']
# Psicologa Diana Batlle - Clinica Psicologica [u'health', u'point_of_interest', u'establishment']
# espais amb historia [u'point_of_interest', u'establishment']
# Vodafone [u'store', u'point_of_interest', u'establishment']
# Outlet TAIKIT! MATARO [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Aules Senior de Mataró [u'point_of_interest', u'establishment']
# First Stop [u'car_repair', u'store', u'point_of_interest', u'establishment']
# Selva [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# Solmanía Sun & Beauty [u'store', u'point_of_interest', u'establishment']
# Esteban Sandoval Alavedra [u'point_of_interest', u'establishment']
# POMA TEXTIL S.L.U. [u'point_of_interest', u'establishment']
# Diaverum [u'health', u'point_of_interest', u'establishment']
# Matec Punt [u'point_of_interest', u'establishment']
# David Castro López [u'electrician', u'point_of_interest', u'establishment']
# Cd [u'store', u'point_of_interest', u'establishment']
# B the travel brand [u'travel_agency', u'point_of_interest', u'establishment']
# Rocablanca Tapisseria [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Super Aliment [u'store', u'point_of_interest', u'establishment']
# Lauca Textil [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Centro de Acupuntura Ramón Feliú [u'health', u'point_of_interest', u'establishment']
# Poppox [u'store', u'point_of_interest', u'establishment']
# Gerard Santamaria [u'point_of_interest', u'establishment']
# Perfumerías Blau [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Sbt la Sabateria [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# Icrea Disseny [u'general_contractor', u'point_of_interest', u'establishment']
# Ford [u'car_dealer', u'store', u'point_of_interest', u'establishment']
# Ona turati [u'point_of_interest', u'establishment']
# Cortefiel (C.C. MATARÓ PARC) [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Druni [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Francisca Ascó García [u'point_of_interest', u'establishment']
# Uniformes El Marino [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Tienda Movistar [u'point_of_interest', u'establishment']
# Ricardo Martínez Muñoz [u'point_of_interest', u'establishment']
# FUREST CASUAL [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Aluminios La Cornisa P [u'point_of_interest', u'establishment']
# La Fábrica del Cartucho Mataró [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Reclamos Ramos [u'point_of_interest', u'establishment']
# Orthoclonic Clínica de ortodoncia - Dr. Juan carlos Díaz Rendón [u'dentist', u'health', u'point_of_interest', u'establishment']
# Institut Alexandre Satorras [u'school', u'point_of_interest', u'establishment']
# Esfirus [u'point_of_interest', u'establishment']
# Mans I Peus [u'beauty_salon', u'point_of_interest', u'establishment']
# Amsel Consulting SL [u'finance', u'point_of_interest', u'establishment']
# Roser Luis Roca - Abogados & Mediadores [u'lawyer', u'point_of_interest', u'establishment']
# Urban Outdoor [u'point_of_interest', u'establishment']
# Clínica Dr. Raurich [u'doctor', u'health', u'point_of_interest', u'establishment']
# Pintores Asociados [u'painter', u'point_of_interest', u'establishment']
# Assoc Grup Integrador Minusval Mataró y Maresme [u'point_of_interest', u'establishment']
# Conversion [u'point_of_interest', u'establishment']
# Casal Gent Gran Parc Municipal de Mataró [u'point_of_interest', u'establishment']
# Veterinaria Animalandia [u'veterinary_care', u'point_of_interest', u'establishment']
# beServices Mataró [u'point_of_interest', u'establishment']
# Visionlab [u'store', u'health', u'point_of_interest', u'establishment']
# Estil Habitat [u'point_of_interest', u'establishment']
# Jaime Poch Padrosa [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Low Key [u'store', u'point_of_interest', u'establishment']
# Catalana Occidente [u'point_of_interest', u'establishment']
# Gasoilmovil.com [u'store', u'point_of_interest', u'establishment']
# Visual Waves Studio [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# DISCOTECA PARTICULAR MATARO [u'night_club', u'point_of_interest', u'establishment']
# Salvia Forma SL [u'point_of_interest', u'establishment']
# Calçats Boixet [u'store', u'point_of_interest', u'establishment']
# inlingua Mataró [u'point_of_interest', u'establishment']
# Baby Jocs Centre De Suport Familiar [u'point_of_interest', u'establishment']
# Showroom del Nado [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Esports Rueda [u'store', u'clothing_store', u'point_of_interest', u'establishment']
# Aquaspai - Underwater Windows [u'general_contractor', u'point_of_interest', u'establishment']
# Mustache Creative [u'point_of_interest', u'establishment']
# Centre de Psicologia Clínica Maresme [u'health', u'point_of_interest', u'establishment']
# MAHLO ESPAÑA SISTEMAS DE REGULACION Y CONTROL S.L. [u'point_of_interest', u'establishment']
# Vesauto Evolucions [u'car_repair', u'point_of_interest', u'establishment']
# Generos de Punto Pera, S.L. [u'point_of_interest', u'establishment']
# Rafael Liñán Moreno [u'point_of_interest', u'establishment']
# Rc Ramatel Telekom, Sl [u'electrician', u'point_of_interest', u'establishment']
# Maymó Tarragona [u'point_of_interest', u'establishment']
# INNOVATECH SOLAR [u'point_of_interest', u'establishment']
# La parada d'en Carles [u'store', u'point_of_interest', u'establishment']
# El Rebollar [u'point_of_interest', u'establishment']
# Rumes Porters [u'point_of_interest', u'establishment']
# Adarsis Grupo Empresarial S.L. [u'car_dealer', u'store', u'point_of_interest', u'establishment']
# alquiler de castillos hinchables [u'point_of_interest', u'establishment']
# Davarth Design [u'point_of_interest', u'establishment']
# Egarsat Mutua Colaboradora con la Seguridad Social nº276 [u'insurance_agency', u'point_of_interest', u'establishment']
# PCM NETEGES I MANTENIMENT [u'home_goods_store', u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Pilar [u'point_of_interest', u'establishment']
# Parc de Rafael Alberti [u'park', u'point_of_interest', u'establishment']
# FOONING RETAIL S.L. [u'point_of_interest', u'establishment']
# Taxi Mataro [u'point_of_interest', u'establishment']
# José Rivas Doblas [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Fusteria [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Staff Sports Serveis Ludics I Esportius,S.L. [u'point_of_interest', u'establishment']
# La Closka [u'point_of_interest', u'establishment']
# Clinica Dental Spa [u'dentist', u'doctor', u'health', u'point_of_interest', u'establishment']
# Grup Plaza Siquier S.L. [u'point_of_interest', u'establishment']
# Acompañamiento consciente embarazo [u'health', u'point_of_interest', u'establishment']
# Esteve Teijin Healtcare [u'health', u'point_of_interest', u'establishment']
# Ganiveteria Can Montserrat Afilador [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Productes Martin [u'point_of_interest', u'establishment']
# Moda Francisca-Velasco [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# L'Obrador [u'point_of_interest', u'establishment']
# nouperruquers [u'hair_care', u'point_of_interest', u'establishment']
# Segunda Mano Mataró [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Laia l'arquera [u'point_of_interest', u'establishment']
# Clínica Dental Roldan [u'dentist', u'beauty_salon', u'spa', u'health', u'point_of_interest', u'establishment']
# World Wide Quality Services, S.L. [u'point_of_interest', u'establishment']
# Canalda Factory S L [u'store', u'point_of_interest', u'establishment']
# Tot Planxa [u'store', u'point_of_interest', u'establishment']
# PIDETUCREDITO.COM [u'finance', u'point_of_interest', u'establishment']
# Ballena Express [u'gas_station', u'point_of_interest', u'establishment']
# GroupBamar [u'point_of_interest', u'establishment']
# Limpiezas y Pintados Mataró [u'point_of_interest', u'establishment']
# Khwaja Traderas S.L. [u'store', u'point_of_interest', u'establishment']
# Administración De Lotería [u'store', u'point_of_interest', u'establishment']
# Camp Municipal de Futbol de La Llàntia [u'premise', u'point_of_interest', u'establishment']
# TOT A MIDA [u'point_of_interest', u'establishment']
# Punt May Moda SL [u'point_of_interest', u'establishment']
# Alarmas Securitas Direct Mataró [u'point_of_interest', u'establishment']
# CEIP Tomàs Viñas [u'school', u'point_of_interest', u'establishment']
# EMPRENLAB CONSULT [u'point_of_interest', u'establishment']
# AVL2000 SL [u'plumber', u'electrician', u'home_goods_store', u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Upuntquatre photo & film [u'point_of_interest', u'establishment']
# SOTAZERO [u'point_of_interest', u'establishment']
# JNR ADVOCATS I ECONOMISTES SA [u'lawyer', u'finance', u'point_of_interest', u'establishment']
# Spafrance SL [u'point_of_interest', u'establishment']
# Innovagrafic [u'store', u'point_of_interest', u'establishment']
# Montse Pedrosa [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# STGLOBAL [u'point_of_interest', u'establishment']
# pingan agencia de viage [u'travel_agency', u'point_of_interest', u'establishment']
# 15-30 Points S L [u'point_of_interest', u'establishment']
# Amsel Assessors [u'finance', u'point_of_interest', u'establishment']
# AurigaIT [u'point_of_interest', u'establishment']
# Miguel López Caparro [u'hair_care', u'point_of_interest', u'establishment']
# Navagrup [u'general_contractor', u'point_of_interest', u'establishment']
# Pista Cero [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Mc Quinn [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Lovable [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Motos Boquet (Mataró) [u'insurance_agency', u'car_repair', u'store', u'point_of_interest', u'establishment']
# Atemporal [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Centre Roldos Mataro [u'beauty_salon', u'hair_care', u'spa', u'health', u'point_of_interest', u'establishment']
# Buca del Tessuto S.L. [u'point_of_interest', u'establishment']
# Bufet Iriarte [u'finance', u'point_of_interest', u'establishment']
# Vilo Mediterráneo S.L. [u'point_of_interest', u'establishment']
# Comissio Obrera Nacional de Catalunya [u'point_of_interest', u'establishment']
# FUSION PAGES, S.L. [u'point_of_interest', u'establishment']
# Bazar Oriente [u'point_of_interest', u'establishment']
# Pau Picasso [u'transit_station', u'point_of_interest', u'establishment']
# Daniel Alsina Colomer [u'point_of_interest', u'establishment']
# Construccions Hidatsa [u'general_contractor', u'point_of_interest', u'establishment']
# 4PARETS [u'real_estate_agency', u'point_of_interest', u'establishment']
# Jimena's Complements [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Oscar Montero Vega [u'point_of_interest', u'establishment']
# Lulú Ferris [u'store', u'point_of_interest', u'establishment']
# ALERTIS BROK S.L [u'point_of_interest', u'establishment']
# Gregal Mix [u'point_of_interest', u'establishment']
# Promocions I Gestió Inmobiliaria Maresme [u'real_estate_agency', u'point_of_interest', u'establishment']
# Manatee Diving [u'store', u'school', u'point_of_interest', u'establishment']
# Your Hair La Boutique de Perruqueria [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Mumcor Textil S.L [u'point_of_interest', u'establishment']
# CASAS [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# H&M [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# CENTRE DE TERÀPIES BEP [u'health', u'point_of_interest', u'establishment']
# cb34 Reformas [u'point_of_interest', u'establishment']
# InnoLectro [u'store', u'point_of_interest', u'establishment']
# Cat 5127 S.L. [u'finance', u'point_of_interest', u'establishment']
# Vistamar Capital SL [u'real_estate_agency', u'point_of_interest', u'establishment']
# Carugatti abogados Mataro [u'lawyer', u'point_of_interest', u'establishment']
# Juegos Kompan SA [u'point_of_interest', u'establishment']
# Bermi Labs [u'point_of_interest', u'establishment']
# MandoCopy [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Líder Mobles [u'furniture_store', u'home_goods_store', u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Aparcaments Marathon [u'gas_station', u'point_of_interest', u'establishment']
# Ipd2004 [u'store', u'health', u'point_of_interest', u'establishment']
# Learnick [u'point_of_interest', u'establishment']
# Cajero automático Caixabank [u'atm', u'finance', u'point_of_interest', u'establishment']
# Catalunya Glass Mataro [u'car_repair', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Dau Nis [u'point_of_interest', u'establishment']
# Estación de servicio Cepsa [u'gas_station', u'point_of_interest', u'establishment']
# EL RENGLE CONSULTORS [u'point_of_interest', u'establishment']
# Mataro Colors [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Farmàcia Corona Subirana [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# triangle traduccions [u'point_of_interest', u'establishment']
# Terabyte Informatics [u'point_of_interest', u'establishment']
# L'Aliança Mataronina (Aliança Mataró) [u'insurance_agency', u'health', u'point_of_interest', u'establishment']
# Arau - Casadevall i associats [u'point_of_interest', u'establishment']
# Ambar Virtual Sets, SL [u'point_of_interest', u'establishment']
# INMOPACA, S.A. [u'real_estate_agency', u'point_of_interest', u'establishment']
# Reexporta [u'finance', u'point_of_interest', u'establishment']
# Foliradiant Maresme [u'point_of_interest', u'establishment']
# Soto Estilistes [u'point_of_interest', u'establishment']
# Josep Garcia. Fotografía de bodas y Estudio fotográfico [u'point_of_interest', u'establishment']
# Industrial Gil BA SL [u'point_of_interest', u'establishment']
# Administración de Lotería N 10 [u'store', u'point_of_interest', u'establishment']
# Isoen Energy [u'point_of_interest', u'establishment']
# K Logistikamataró [u'point_of_interest', u'establishment']
# Euskadi [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Global Theratyj [u'physiotherapist', u'health', u'point_of_interest', u'establishment']
# Micropigmentación Duarte [u'beauty_salon', u'point_of_interest', u'establishment']
# Viajes Senda Sur [u'travel_agency', u'point_of_interest', u'establishment']
# Dorma Ibérica Delegación Cataluña [u'point_of_interest', u'establishment']
# Catalana de Seguretat Integral 74 S.L. [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Asesoría Mava [u'finance', u'point_of_interest', u'establishment']
# José María Salvaña Ongil [u'point_of_interest', u'establishment']
# Synergy Telecomunicacions [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Vicky Navas Perruqueria Unisex [u'point_of_interest', u'establishment']
# Jordi Valls Durán [u'point_of_interest', u'establishment']
# Biblioteca [u'library', u'point_of_interest', u'establishment']
# Sala Face Mataro [u'night_club', u'point_of_interest', u'establishment']
# LEx & Co Advocats I Assesors [u'lawyer', u'point_of_interest', u'establishment']
# Immobiliaria Molina [u'real_estate_agency', u'point_of_interest', u'establishment']
# Persianas de Casa, S.C.P. [u'point_of_interest', u'establishment']
# Tec-Center [u'point_of_interest', u'establishment']
# Grupo Marte Alquiler de Coches y Vehículos Industriales [u'car_rental', u'point_of_interest', u'establishment']
# Tintorería Pressto Mataró [u'laundry', u'point_of_interest', u'establishment']
# Seton [u'point_of_interest', u'establishment']
# MaletasDarbra [u'store', u'point_of_interest', u'establishment']
# Técnicas Ceercamet [u'point_of_interest', u'establishment']
# Mitsubishi Motors [u'car_dealer', u'store', u'point_of_interest', u'establishment']
# FARMÀCIA SPA VERA [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# Taller Alemania [u'car_repair', u'point_of_interest', u'establishment']
# Domingo Cano Palomino [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# SAT Subministraments Industreals [u'point_of_interest', u'establishment']
# Garmax Products SL [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Academia Bull Control Mataró [u'point_of_interest', u'establishment']
# Ametller Economistes SLP [u'finance', u'point_of_interest', u'establishment']
# MF Instruments [u'point_of_interest', u'establishment']
# Graphic Factory Digital [u'point_of_interest', u'establishment']
# CaixaBank [u'atm', u'finance', u'point_of_interest', u'establishment']
# Diputació Provincial de Barcelona [u'local_government_office', u'point_of_interest', u'establishment']
# Gran Basar [u'store', u'point_of_interest', u'establishment']
# Suit By Montana [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Khorny Mazen [u'dentist', u'health', u'point_of_interest', u'establishment']
# Apothekamed, S.A. [u'health', u'point_of_interest', u'establishment']
# Artijoc [u'store', u'point_of_interest', u'establishment']
# International Rural School Granja Escola Casa Nostra [u'school', u'point_of_interest', u'establishment']
# Joyeria Diaz [u'jewelry_store', u'store', u'point_of_interest', u'establishment']
# ESTEVE ORTOPEDIA A MIDA SL [u'shoe_store', u'store', u'health', u'point_of_interest', u'establishment']
# Moviagri Jusa Sl [u'general_contractor', u'point_of_interest', u'establishment']
# Style Deluxe Perruquers [u'beauty_salon', u'hair_care', u'spa', u'health', u'point_of_interest', u'establishment']
# SEDNA Engineering & Energy [u'point_of_interest', u'establishment']
# Neteges Llauder [u'point_of_interest', u'establishment']
# MiMs Costura [u'store', u'point_of_interest', u'establishment']
# ilurotex [u'point_of_interest', u'establishment']
# La Font Del Faune [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Tienda Moto [u'store', u'point_of_interest', u'establishment']
# Bazar el kasr al kabir [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# NEMEX Abogados Fiscalistas [u'finance', u'point_of_interest', u'establishment']
# The Little Bone [u'point_of_interest', u'establishment']
# Notaría Espinosa & G. Ortiz [u'finance', u'point_of_interest', u'establishment']
# Dentell S.L. [u'general_contractor', u'point_of_interest', u'establishment']
# Clinica Dental Motaró [u'dentist', u'health', u'point_of_interest', u'establishment']
# Factoría de Marketing I Comunicació S. L. [u'point_of_interest', u'establishment']
# Club Patinatge Artístic Iluro [u'point_of_interest', u'establishment']
# Joaquín Gelabert Illa [u'jewelry_store', u'store', u'point_of_interest', u'establishment']
# TICBCN - Servicios IT Informática para pymes [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# The Beauty Corner [u'beauty_salon', u'point_of_interest', u'establishment']
# Centro Médico Quirúrgico Mataró [u'health', u'point_of_interest', u'establishment']
# ASSOCIACIÓ CANNÁBICA DEL MARESME (MATARÓ) [u'point_of_interest', u'establishment']
# matarolux 6 [u'lodging', u'point_of_interest', u'establishment']
# Miguel Sojo [u'point_of_interest', u'establishment']
# Antonio López y Sonia López Podólogos [u'doctor', u'health', u'point_of_interest', u'establishment']
# Retolins [u'point_of_interest', u'establishment']
# Aplex, Control de Plagas [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Òmnium Cultural Mataró Maresme [u'point_of_interest', u'establishment']
# Luzmariel [u'point_of_interest', u'establishment']
# Partit Dels Socialistes de Catalunya [u'point_of_interest', u'establishment']
# Ginés Sánchez [u'point_of_interest', u'establishment']
# Fundació Friends [u'school', u'point_of_interest', u'establishment']
# English Connection [u'point_of_interest', u'establishment']
# CORTINES CASTANY- Cortines i Roba per la LLar [u'point_of_interest', u'establishment']
# Schunk [u'point_of_interest', u'establishment']
# Asesores Corporativos Its Possible SL - Captain Cool [u'store', u'point_of_interest', u'establishment']
# verticals mataro [u'painter', u'general_contractor', u'point_of_interest', u'establishment']
# ahmedsegundamano [u'point_of_interest', u'establishment']
# D-m2 [u'point_of_interest', u'establishment']
# WELLWAY S.L. [u'storage', u'point_of_interest', u'establishment']
# Barceló Cars [u'car_dealer', u'store', u'point_of_interest', u'establishment']
# Escola Àngela Bransuela [u'school', u'point_of_interest', u'establishment']
# Proxim [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# Cial FB [u'point_of_interest', u'establishment']
# Maresme 2000 Correduria de Seguros SA [u'point_of_interest', u'establishment']
# ESTHER SUBIRANA [u'point_of_interest', u'establishment']
# Calçats Boixet [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# Raúl Cardona Blanco [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Herbanatur [u'store', u'point_of_interest', u'establishment']
# antenistabarcelona.com - Instalación de antenas TDT, Parabólicas, Interfonos, Cámaras (CCTV) y Wifi. [u'point_of_interest', u'establishment']
# TecnoCampus Mataró-Maresme [u'university', u'point_of_interest', u'establishment']
# MATARO COLORS S.L. [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# CCOO Unió Intercomarcal Vallès Oriental, Maresme, Osona [u'point_of_interest', u'establishment']
# Motos Dimoto [u'car_dealer', u'store', u'point_of_interest', u'establishment']
# 3g Mobils House [u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Pistas de Skate [u'point_of_interest', u'establishment']
# LLar d'infants Anca [u'school', u'point_of_interest', u'establishment']
# World Complements S.L. [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Towerik SL [u'point_of_interest', u'establishment']
# Doctora Pilar Roca [u'doctor', u'health', u'point_of_interest', u'establishment']
# RT2 [u'furniture_store', u'car_repair', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Isabel [u'point_of_interest', u'establishment']
# Punt Roma [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Brodats Bropunt [u'point_of_interest', u'establishment']
# Interseleccion SL [u'point_of_interest', u'establishment']
# Red Civil SLP [u'point_of_interest', u'establishment']
# Energies Renovables [u'point_of_interest', u'establishment']
# Pau Picasso [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# ...
# Tres Roques [u'school', u'point_of_interest', u'establishment']
# Expendeduria Número 446 [u'store', u'point_of_interest', u'establishment']
# Taller d'arts plàstiques Amalia17 [u'point_of_interest', u'establishment']
# Míriam Pons [u'point_of_interest', u'establishment']
# Peluquería Pepita [u'beauty_salon', u'hair_care', u'point_of_interest', u'establishment']
# PiscoBcn [u'liquor_store', u'store', u'point_of_interest', u'establishment']
# Rinco Ultrasonics [u'store', u'point_of_interest', u'establishment']
# Automoviles gravina [u'car_repair', u'point_of_interest', u'establishment']
# Costa [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Escola Public Camí Del Cros [u'school', u'point_of_interest', u'establishment']
# Géneros de Punto Fabres [u'point_of_interest', u'establishment']
# marimon ebenistes scp [u'point_of_interest', u'establishment']
# Marcs A Mida Bona S L [u'store', u'point_of_interest', u'establishment']
# CaixaBank [u'bank', u'finance', u'point_of_interest', u'establishment']
# Allianz Seguros [u'point_of_interest', u'establishment']
# Carpinteria D'Alumini Marathon J. Campos [u'point_of_interest', u'establishment']
# Waldo Complementos S.L. [u'point_of_interest', u'establishment']
# Reformas Nou Sol SL [u'point_of_interest', u'establishment']
# Oficina Deganat [u'courthouse', u'point_of_interest', u'establishment']
# Maquinas de coser Ramon Polo [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Hercadi Woman S.L. [u'point_of_interest', u'establishment']
# Duplex [u'real_estate_agency', u'general_contractor', u'point_of_interest', u'establishment']
# Construccions Metal Liques Canellas [u'general_contractor', u'point_of_interest', u'establishment']
# CAMP MUNICIPAL CAMÌ DEL MIG [u'point_of_interest', u'establishment']
# M Cerraje [u'car_repair', u'point_of_interest', u'establishment']
# Wamwaki S L [u'point_of_interest', u'establishment']
# Aula de Teatre [u'university', u'point_of_interest', u'establishment']
# Talleres Llorens Planas S.L. [u'point_of_interest', u'establishment']
# Saba Aparcamientos S A [u'parking', u'point_of_interest', u'establishment']
# Mudanzas Canobox [u'moving_company', u'storage', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Tokut [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Proyectos Ángel García [u'home_goods_store', u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Webbing Barcelona [u'point_of_interest', u'establishment']
# Institut Europeu De Formació Profesional [u'point_of_interest', u'establishment']
# tallers Metallurgics Garcia [u'car_repair', u'point_of_interest', u'establishment']
# catalana de treballs [u'point_of_interest', u'establishment']
# Ac Consulti'N [u'point_of_interest', u'establishment']
# María José Sarrionandia Chacón [u'lawyer', u'point_of_interest', u'establishment']
# emilià fusteria al detall [u'point_of_interest', u'establishment']
# Viada® [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Franiluro Paper Major Papereria [u'point_of_interest', u'establishment']
# Robot Coupe Snc [u'store', u'point_of_interest', u'establishment']
# Residència geriàtrica La Vostra Llar Voramar-Mataró (Barcelona) [u'health', u'point_of_interest', u'establishment']
# El racó de l'Isaac - Venda de productes convencionals i ecològics a granel [u'store', u'point_of_interest', u'establishment']
# El Periódico [u'point_of_interest', u'establishment']
# Irlanda [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Novagest Consultoría Empresarial [u'point_of_interest', u'establishment']
# Centre Mèdic Alomar [u'point_of_interest', u'establishment']
# Salesians [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Centre de Psicoteràpia BREU del Maresme, Psicolegs a Mataró [u'health', u'point_of_interest', u'establishment']
# Quart Textil - Expertos en moda femenina [u'point_of_interest', u'establishment']
# KIKO Milano [u'store', u'point_of_interest', u'establishment']
# Leman 33 S.L. [u'general_contractor', u'point_of_interest', u'establishment']
# Plaça Salvador Dalí [u'park', u'point_of_interest', u'establishment']
# KBMúsics [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Asipa Viatges [u'travel_agency', u'point_of_interest', u'establishment']
# beauty glamour [u'store', u'point_of_interest', u'establishment']
# MQCORTINAS [u'point_of_interest', u'establishment']
# CIDIE Centro de Investigación, Formación y Desarrollo de la Inteligencia Emocional [u'point_of_interest', u'establishment']
# Abanik Rent & Events [u'point_of_interest', u'establishment']
# Maresme Sertec SL [u'general_contractor', u'point_of_interest', u'establishment']
# Bernat Batlle Montserrat [u'point_of_interest', u'establishment']
# JSM Inforedes,S.L. [u'point_of_interest', u'establishment']
# Money Exchange Agente [u'bank', u'finance', u'store', u'point_of_interest', u'establishment']
# Iniciativas Comerciales Electricas SA [u'point_of_interest', u'establishment']
# Papelería Montserrat Francesch [u'book_store', u'store', u'point_of_interest', u'establishment']
# Autorentat l'Arquera [u'car_wash', u'point_of_interest', u'establishment']
# Anna Borrell [u'point_of_interest', u'establishment']
# Glassdrive [u'car_repair', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Accsen Instrumental S.L.L. [u'point_of_interest', u'establishment']
# Ricardo Martí López - Amor [u'doctor', u'health', u'point_of_interest', u'establishment']
# Biblioteca Antoni Comas [u'library', u'point_of_interest', u'establishment']
# Carpintería J Pons [u'point_of_interest', u'establishment']
# Taller De Joieria [u'jewelry_store', u'store', u'point_of_interest', u'establishment']
# Pneumàtics Nous i D'Ocasio [u'car_repair', u'store', u'point_of_interest', u'establishment']
# Creu Roja [u'point_of_interest', u'establishment']
# Katy Caballero [u'health', u'point_of_interest', u'establishment']
# Ecoline10 [u'point_of_interest', u'establishment']
# MENDEZ PROMOTORA-CONSTRUCTORA [u'general_contractor', u'point_of_interest', u'establishment']
# Turó Pell [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Ross [u'hair_care', u'point_of_interest', u'establishment']
# La Oca Codi [u'point_of_interest', u'establishment']
# Disset [u'real_estate_agency', u'point_of_interest', u'establishment']
# m-sergraf [u'point_of_interest', u'establishment']
# Librería Márquez [u'book_store', u'store', u'point_of_interest', u'establishment']
# Farmàcia Montserrat Barberà Casajuana [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# MGS Seguros [u'point_of_interest', u'establishment']
# LIMPIEZAS LINA, SL. [u'point_of_interest', u'establishment']
# agencia Inmobiliaria Iluro [u'real_estate_agency', u'point_of_interest', u'establishment']
# Perruqueria Eva [u'hair_care', u'point_of_interest', u'establishment']
# Limpiezas González [u'point_of_interest', u'establishment']
# Can boada [u'general_contractor', u'point_of_interest', u'establishment']
# AC Flo Dur SL [u'point_of_interest', u'establishment']
# Viajes Marsans [u'travel_agency', u'point_of_interest', u'establishment']
# Plaça Dosrius [u'park', u'point_of_interest', u'establishment']
# Pedro Fernández Almodóvar [u'point_of_interest', u'establishment']
# INOXMAT [u'hardware_store', u'store', u'point_of_interest', u'establishment']
# Vodafone [u'store', u'point_of_interest', u'establishment']
# Reformas Prosomni S.L. [u'general_contractor', u'point_of_interest', u'establishment']
# Clínica Dental Salomó [u'dentist', u'health', u'point_of_interest', u'establishment']
# camisetas BlueRed [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Farmàcia Romances [u'pharmacy', u'store', u'health', u'point_of_interest', u'establishment']
# Marpe [u'point_of_interest', u'establishment']
# Suhimar Suministros Hidraulicos [u'point_of_interest', u'establishment']
# Isidoro Pérez Vizcaíno [u'car_repair', u'point_of_interest', u'establishment']
# Sala montmartre [u'point_of_interest', u'establishment']
# Antonio Navas Bravo [u'point_of_interest', u'establishment']
# panoramics can quirze [u'point_of_interest', u'establishment']
# Tarot Pere Dalmau [u'book_store', u'store', u'point_of_interest', u'establishment']
# Centro Auditivo Amplifon Mataró [u'store', u'health', u'point_of_interest', u'establishment']
# ValentiNet [u'car_wash', u'point_of_interest', u'establishment']
# Sasa Textil [u'point_of_interest', u'establishment']
# Perruqueria Asumpta [u'hair_care', u'point_of_interest', u'establishment']
# Aurgi [u'car_repair', u'electronics_store', u'store', u'point_of_interest', u'establishment']
# Ctra. Mata [u'transit_station', u'point_of_interest', u'establishment']
# Manuel Vázquez Tundidor [u'point_of_interest', u'establishment']
# Pulidos Lozano [u'point_of_interest', u'establishment']
# DOCOR SL [u'point_of_interest', u'establishment']
# Grup 5 [u'car_repair', u'store', u'point_of_interest', u'establishment']
# Escola Montserrat Solà [u'school', u'point_of_interest', u'establishment']
# Tanatori Mataró [u'point_of_interest', u'establishment']
# Enmarcación a medida [u'store', u'point_of_interest', u'establishment']
# COCOA Mataró [u'night_club', u'point_of_interest', u'establishment']
# Generos de Punto Victrix SL [u'point_of_interest', u'establishment']
# Pou 13 AMSA [u'museum', u'point_of_interest', u'establishment']
# Planxa İ Pintura [u'car_repair', u'point_of_interest', u'establishment']
# Assistència I Gestió Integral [u'point_of_interest', u'establishment']
# Clínica Dental Dr.Helbig [u'dentist', u'health', u'point_of_interest', u'establishment']
# Saterra Joiers S.A. [u'jewelry_store', u'store', u'point_of_interest', u'establishment']
# Sauri [u'point_of_interest', u'establishment']
# DENTXDENT [u'dentist', u'health', u'point_of_interest', u'establishment']
# ZARA [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# riegos alex [u'store', u'general_contractor', u'point_of_interest', u'establishment']
# Reparació Calçat Copia De Claus [u'point_of_interest', u'establishment']
# Cuines Chacon [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Plaça França [u'transit_station', u'point_of_interest', u'establishment']
# EQlogic Computers [u'point_of_interest', u'establishment']
# Anna Peluquería [u'beauty_salon', u'point_of_interest', u'establishment']
# Cajero automático Caixabank [u'atm', u'finance', u'point_of_interest', u'establishment']
# Mútua General de Catalunya [u'insurance_agency', u'health', u'point_of_interest', u'establishment']
# Belinda Navarro Carrera [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Relemat [u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Taller De Pianos Jordi Cabezudo [u'electronics_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# bikeride costa brava [u'point_of_interest', u'establishment']
# Via Europa [u'transit_station', u'point_of_interest', u'establishment']
# Globalstudy 2013 Sl [u'point_of_interest', u'establishment']
# Verde Limón Mataró [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Blau Artic [u'point_of_interest', u'establishment']
# Pajareria Mataro [u'store', u'point_of_interest', u'establishment']
# Centre de Podologia Rosa M. Gómez [u'health', u'point_of_interest', u'establishment']
# Serveis Ocupacional D'Insercio Jaume Isern [u'point_of_interest', u'establishment']
# Tir Esportiu Mataró [u'point_of_interest', u'establishment']
# Juan Antonio Rodón Bellalta [u'point_of_interest', u'establishment']
# Espai Terapèutic Maresme [u'doctor', u'health', u'point_of_interest', u'establishment']
# Artex [u'point_of_interest', u'establishment']
# Escola Pública Cirera [u'school', u'point_of_interest', u'establishment']
# MRG video y fotografia [u'point_of_interest', u'establishment']
# Ediet SL [u'general_contractor', u'point_of_interest', u'establishment']
# Plaça Ciutat de Cehegín [u'park', u'premise', u'point_of_interest', u'establishment']
# Copisteria Can Prims [u'point_of_interest', u'establishment']
# Jardins de l'Antic Escorxador [u'park', u'premise', u'point_of_interest', u'establishment']
# Estructures i Solucions del Formigó [u'general_contractor', u'point_of_interest', u'establishment']
# A.L.C. Instalación de Canalones [u'plumber', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# bed´s [u'furniture_store', u'home_goods_store', u'store', u'lodging', u'point_of_interest', u'establishment']
# GILBO S.A. [u'point_of_interest', u'establishment']
# Arel 2002 S.L. [u'point_of_interest', u'establishment']
# Contrafoc [u'point_of_interest', u'establishment']
# Trans X Tar S L [u'point_of_interest', u'establishment']
# Medicare System [u'point_of_interest', u'establishment']
# José Rovira Serra [u'point_of_interest', u'establishment']
# Sunglass Hut [u'store', u'point_of_interest', u'establishment']
# Sevytex [u'point_of_interest', u'establishment']
# Serra Sis [u'shoe_store', u'store', u'point_of_interest', u'establishment']
# Grup Esinde [u'point_of_interest', u'establishment']
# Viatges Azul SL [u'travel_agency', u'point_of_interest', u'establishment']
# Jz Project And Construction Management Slp [u'point_of_interest', u'establishment']
# ASOC. VOLUNTARIOS COOPERANTES [u'point_of_interest', u'establishment']
# Stradivarius [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Alonso Pozo Torres [u'point_of_interest', u'establishment']
# R S Interdecoracion 2000 S L [u'point_of_interest', u'establishment']
# Lluis Viladevall - Mataró Park [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Mataró Televisió [u'point_of_interest', u'establishment']
# Carglass® - reparación de lunas [u'car_repair', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# CAMPUS XAVI [u'point_of_interest', u'establishment']
# Laboratorio Dr.F.Echevarne [u'dentist', u'health', u'point_of_interest', u'establishment']
# Inserciones Iluro, S.L. [u'point_of_interest', u'establishment']
# Via Europa [u'bus_station', u'transit_station', u'point_of_interest', u'establishment']
# Vodafone [u'store', u'point_of_interest', u'establishment']
# Tienda MASSANA [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# koovik [u'point_of_interest', u'establishment']
# Toribio Bisbal [u'shoe_store', u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Neumáticos Mataró [u'car_repair', u'store', u'point_of_interest', u'establishment']
# Das Welt Auto. [u'car_dealer', u'store', u'point_of_interest', u'establishment']
# Primadonna [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Clarel [u'store', u'point_of_interest', u'establishment']
# Tienda Movistar [u'point_of_interest', u'establishment']
# Envialia [u'point_of_interest', u'establishment']
# IM Multimarca Taller De Reparació [u'store', u'point_of_interest', u'establishment']
# Victoria Fernández García [u'beauty_salon', u'point_of_interest', u'establishment']
# ARDG Consulting [u'point_of_interest', u'establishment']
# Cristina Barnet. Economista. Asesoría y Gestoría. Pymes, Profesionales y Particulares. [u'accounting', u'lawyer', u'finance', u'point_of_interest', u'establishment']
# Ilurogest S L [u'real_estate_agency', u'point_of_interest', u'establishment']
# Ayca [u'furniture_store', u'home_goods_store', u'store', u'point_of_interest', u'establishment']
# Estilista de Cabell Carles SL [u'hair_care', u'point_of_interest', u'establishment']
# Alarmas Barcelona [u'point_of_interest', u'establishment']
# Urban Women [u'clothing_store', u'store', u'point_of_interest', u'establishment']
# Abanik Rent & Events [u'point_of_interest', u'establishment']
# Acadèmia Teens Center [u'health', u'school', u'point_of_interest', u'establishment']
# Benito Corrales Largo [u'point_of_interest', u'establishment']
# Bufete Graupera [u'point_of_interest', u'establishment']
# Munzia Gest De Serv Sanitarios [u'health', u'point_of_interest', u'establishment']
# Promocions Urbanistiques De Mataró S A [u'real_estate_agency', u'point_of_interest', u'establishment']

# %% [markdown]
# ## Save Data Set

# %%
#### Final create the dataset
file_name="/Users/juancarlosmunoz/Dropbox/Obsogenic_Project/02_Output_DataBase/DataBase_v2_Feb2018_grids.xlsx"
df = pd.DataFrame(final_ds)
writer_orig = pd.ExcelWriter(file_name, engine='xlsxwriter')
df.to_excel(writer_orig, index=False, sheet_name='report')
writer_orig.save()

# %% [markdown]
# ### Extra Checks (no need to run)

# %%
## Check whether especific store was saved
df.loc[df['google_id'] == 'ChIJAQCEozC1pBIRzf1jRrgKvcQ']
# Out:
#                              categ                    google_id  \
# 243  establecimientos polivalentes  ChIJAQCEozC1pBIRzf1jRrgKvcQ
#
#                               name_check  \
# 243  [pica&pica, 24h, rocafonda, mataró]
#
#                                          place_address  place_lat  place_lng  \
# 243  Carrer del Poeta Josep Punsola, 46, 08304 Mata...  41.549236    2.45097
#
#                          place_name  \
# 243  Pica&Pica 24h Rocafonda Mataró
#
#                                            place_types  \
# 243  [supermarket, grocery_or_supermarket, store, f...
#
#                                              place_web
# 243  https://maps.google.com/?cid=14176498988603407821

# %%
for typ in types_accepted:
    res1=google_places.nearby_search(lat_lng=grids_data[1175],radius=50,type='bakery')
    # For more than 20 results
    print "---- %s -----" %(typ)
    read_result(res1)
    try:
        res2 = google_places.nearby_search(pagetoken=res1.next_page_token)
        print res2
        read_result(res2)
        try:
            res3 = google_places.nearby_search(pagetoken=res2.next_page_token)
            print res3
            read_result(res3)
            try:
                res4 = google_places.nearby_search(pagetoken=res3.next_page_token)
                print res4
                read_result(res4)
            except:
                pass    
        except:
            pass   
    except:
        pass
# Out:
# ---- bakery -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- bar -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- cafe -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- convenience_store -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- establishment -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- food -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- grocery_or_supermarket -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- liquor_store -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- meal_delivery -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- meal_takeaway -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- restaurant -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- shopping_mall -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A
# ---- store -----
# Manuela Ruiz Requena [u'bakery', u'store', u'food', u'point_of_interest', u'establishment'] ChIJYyxZWAW1pBIRrClqpIopr9A

# %%
print types_accepted
# Out:
# ['bakery', 'bar', 'cafe', 'convenience_store', 'establishment', 'food', 'grocery_or_supermarket', 'liquor_store', 'meal_delivery', 'meal_takeaway', 'restaurant', 'shopping_mall', 'store', 'supermarket']

# %%
ChIJAQCEozC1pBIRzf1jRrgKvcQ
